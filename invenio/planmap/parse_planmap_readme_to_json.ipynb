# %% [markdown]
# # PLANMAP Readme to JSON metadata file
#
# In this note we will translate a Planmap package Readme.md (Markdown) to a JSON file and validate it against the GMAP package jsonschema, then save it.

# %%
PUB_DIR = 'data/publish_data/archive/'
ZIP_DIR = 'data/publish_data/zip/'

# %%
readme_file = f'{PUB_DIR}/mars/PM-MAR-MS-Arsinoes/README.md'

with open(readme_file, 'r') as fp:
    readme = fp.read()

# %%
print(readme)
# Out:
# ---
# <img src="./document/PM-MAR-MS-Arsinoes.browse.png" width="800"/>
#
# | Field                                                        | Description                                                  |
# | ------------------------------------------------------------ | ------------------------------------------------------------ |
# | Map name (PM_ID)                                             | PM-MAR-MS-Arsinoes                                           |
# | Map version                                                  | 03                                        |
# | Target body                                                  | Mars                                                         |
# | Title of map                                                 | Geological Map of Arsinoes and Pyrrhae Chaos, Mars           |
# | Bounding box - Min Lat                                       | -12                                                          |
# | Bounding box - Max Lat                                       | -5.8                                                         |
# | Bounding box - Min Lon (0-360)                               | 329.7                                                        |
# | Bounding box - Max Lon (0-360)                               | 334.5                                                        |
# | Author(s)                                                    | E. Luzzi, A.P. Rossi                                         |
# | Type                                                         | Preliminary                                                  |
# | Output scale                                                 | 1:3.000.000                                                  |
# | Original Coordinate Reference System                         | Projected Coordinate System: Equirectangular Projection: Plate_Carree false_easting: 0.00000000 false_northing: 0.00000000 central_meridian: 0.00000000 Linear Unit: Meter Geographic Coordinate System: GCS_Geographic_Coordinate_System Datum: D_MARS Prime Meridian: Reference Meridian Angular Unit: Degree |
# | Data used                                                    | MOLA Elevation Model MEGDR (463 m/pixel)CTX mosaic by MurrayLabCTX DTM (18 m)HiRISE RED (0,25 m/pixel) |
# | Standards adhered to                                         | Planmap mapping standards document                           |
# | DOI                                                          |                                                              |
# | Aims (one sentence)                                          | Morpho-stratigraphic mapping                                 |
# | Short description                                            | This map shows the contacts between the disrupted bedrock of the Chaotic terrain Units and the overlying sedimentary units. In addition, it shows the distribution of the graben/fissures and pit chains that are probably related to an intense past of magmatic activity and calderic collapse. In order to better characterize the mineralogical characteristics of the occurring deposits, also spectral analyses were tried out on the only available CRISM cube in the area (still in progress) |
# | Related products (cross link to other Planmap products)      |                                                              |
# | Units Definition                                             | Post-collapse craters, PCC, 51-160-44Cap Unit, CAP, 182-162-255Light-toned Layered deposits units, LLD, 77-205-255High Thermal Inertia Chaotic terrain, ChH, 227-28-28Knobby Terrain, ChK, 255-127-0Fractured Plains, ChF, 255-238-3 |
# | Stratigraphic info (e.g. production function used)           | N/A                                                          |
# | Other comments (reviewer comments, notes on post-processing) |                                                              |
# | Heritage used                                                | Glotch and Christensen 2005                                  |
# | Link to other repositories                                   |                                                              |
# | Acknowledgements beyond Planmap                              | N/A                                                          |

# %%
# Import Planmap package
#
import api.planmap

from importlib import reload
reload(api.planmap)

table = api.planmap.markdown2json(readme)

api.planmap.validate(table)

# %%
def validate_readme(readme_file:str) -> dict:
    """
    Return 'readme' as a json if validatation is succesfull
    
    Validation JSONSchema: `api.planmap.README_SCHEMA`
    """
    import api.planmap
    
    with open(readme_file, 'r') as fp:
        readme = fp.read()

    table = api.planmap.markdown2json(readme)

    api.planmap.validate(table)
    
    return table

# %%
import itertools

# %%
import os
from glob import glob

# Look for Planmap packages' Readme in every body, Mars, Mercury, Moon
#

def resolve_paths(path_template="{basedir}/{bodies}/PM-*", **kwargs):
    # Ex. kwargs: basedir=PUB_DIR, bodies=['mars','mercury','moon']
    #
    for k,v in kwargs.items():
        kwargs[k] = [v] if isinstance(v, str) else v
        
    product = [ v for v in itertools.product(*kwargs.values()) ]
    path_values = [ { k:v for k,v in zip(kwargs.keys(),prod) } for prod in product ]

    paths = []
    for kwargs in path_values:
        # Resolve path template for current 'kwargs'
        #
        dirs_regex = path_template.format(**kwargs)
        try:
            pkg_dirs = glob(f"{dirs_regex}")
        except:
            return None
        
        paths.extend(pkg_dirs)
            
    return paths

# %%
pkg_dirs = resolve_paths(path_template="{basedir}/{bodies}/PM-*", basedir=PUB_DIR, bodies=['mars','mercury','moon'])

table_all = {}

for pkg_dir in pkg_dirs:
    pkg_name = os.path.basename(pkg_dir)
    for filepath in glob(f"{pkg_dir}/*"):
        if os.path.basename(filepath).lower() == 'readme.md':
            print('--', filepath)
            table = validate_readme(filepath)
            assert pkg_name not in table_all
            table_all.update({ pkg_name: table })
# Out:
# -- data/publish_data/archive//mars/PM-MAR-MS-Crommelin/README.md
# -- data/publish_data/archive//mars/PM-MAR-C-Crommelin/README.md
# -- data/publish_data/archive//mars/PM-MAR-D-Oxia_Planum/README.md
# -- data/publish_data/archive//mars/PM-MAR-D-Crommelin/README.md
# -- data/publish_data/archive//mars/PM-MAR-MS-Arsinoes/README.md
# -- data/publish_data/archive//mars/PM-MAR-SI-Crommelin/README.MD
# -- data/publish_data/archive//mars/PM-MAR-D-Gale_Murray/readme.md
# -- data/publish_data/archive//mars/PM-MAR-C-Arsinoes/README.md
# -- data/publish_data/archive//mars/PM-MAR-D-Jezero/README.md
# -- data/publish_data/archive//mars/PM-MAR-D-Gale_Kimberley/README.md
# -- data/publish_data/archive//mercury/PM-MER-C-H05_SU/README.md
# -- data/publish_data/archive//mercury/PM-MER-GS-Rachmaninoff_5cc/README.md
# -- data/publish_data/archive//mercury/PM-MER-MS-Beethoven/README.md
# -- data/publish_data/archive//mercury/PM-MER-MS-H14_5cc/README.MD
# -- data/publish_data/archive//mercury/PM-MER-MS-H10_5cc/README.MD
# -- data/publish_data/archive//mercury/PM-MER-SI-Rembrandt/README.md
# -- data/publish_data/archive//mercury/PM-MER-MS-H05_5cc/README.md
# -- data/publish_data/archive//mercury/PM-MER-D-Rembrandt/README.md
# -- data/publish_data/archive//mercury/PM-MER-C-Rembrandt/README.md
# -- data/publish_data/archive//mercury/PM-MER-MS-Lermontov/README.md
# -- data/publish_data/archive//mercury/PM-MER-MS-H14_3cc/README.MD
# -- data/publish_data/archive//mercury/PM-MER-C-H05/README.md
# -- data/publish_data/archive//mercury/PM-MER-MS-H02_3cc/README.md
# -- data/publish_data/archive//mercury/PM-MER-MS-H10_3cc/README.MD
# -- data/publish_data/archive//mercury/PM-MER-MS-Rembrandt/README.md
# -- data/publish_data/archive//mercury/PM-MER-MS-H05_3cc/README.md
# -- data/publish_data/archive//mercury/PM-MER-C-Beethoven/README.md
# -- data/publish_data/archive//moon/PM-MOO-MS-Apollo11/README.md
# -- data/publish_data/archive//moon/PM-MOO-C-SPAA1_SU/README.md
# -- data/publish_data/archive//moon/PM-MOO-GS-SPAApollo_Detail/README.md
# -- data/publish_data/archive//moon/PM-MOO-C-SPAApollo/README.md
# -- data/publish_data/archive//moon/PM-MOO-C-SPAApollo_SU/README.md
# -- data/publish_data/archive//moon/PM-MOO-MS-Apollo12/README.md
# -- data/publish_data/archive//moon/PM-MOO-MS-SPAApollo/README.md
# -- data/publish_data/archive//moon/PM-MOO-D-YutuGPR/README.md
# -- data/publish_data/archive//moon/PM-MOO-MS-Copernicus/README.md

# %%
import pandas as pd

pd.set_option('display.max_columns',100)

pd.__version__
# Out:
# '1.4.3'

# %%
pd.DataFrame(table_all).T
# Out:
#                                       Map name (PM_ID) Target body  \
# PM-MAR-MS-Crommelin                PM-MAR-MS-Crommelin        Mars
# PM-MAR-C-Crommelin                  PM-MAR-C-Crommelin        Mars
# PM-MAR-D-Oxia_Planum              PM-MAR-D-Oxia_Planum        Mars
# PM-MAR-D-Crommelin                  PM-MAR-D-Crommelin        Mars
# PM-MAR-MS-Arsinoes                  PM-MAR-MS-Arsinoes        Mars
# PM-MAR-SI-Crommelin                PM-MAR-SI-Crommelin        Mars
# PM-MAR-D-Gale_Murray              PM-MAR-D-Gale_Murray        Mars
# PM-MAR-C-Arsinoes                    PM-MAR-C-Arsinoes        Mars
# PM-MAR-D-Jezero                        PM-MAR-D-Jezero        Mars
# PM-MAR-D-Gale_Kimberley        PM-MAR-D-Gale_Kimberley        Mars
# PM-MER-C-H05_SU                        PM-MER-C-H05_SU     Mercury
# PM-MER-GS-Rachmaninoff_5cc  PM-MER-GS-Rachmaninoff_5cc     Mercury
# PM-MER-MS-Beethoven                PM-MER-MS-Beethoven     Mercury
# PM-MER-MS-H14_5cc                    PM-MER-MS-H14_5cc     Mercury
# PM-MER-MS-H10_5cc                    PM-MER-MS-H10_5cc     Mercury
# PM-MER-SI-Rembrandt                PM-MER-SI-Rembrandt     Mercury
# PM-MER-MS-H05_5cc                    PM-MER-MS-H05_5cc     Mercury
# PM-MER-D-Rembrandt                  PM-MER-D-Rembrandt     Mercury
# PM-MER-C-Rembrandt                  PM-MER-C-Rembrandt     Mercury
# PM-MER-MS-Lermontov                PM-MER-MS-Lermontov     Mercury
# PM-MER-MS-H14_3cc                    PM-MER-MS-H14_3cc     Mercury
# PM-MER-C-H05                              PM-MER-C-H05     Mercury
# PM-MER-MS-H02_3cc                    PM-MER-MS-H02_3cc     Mercury
# PM-MER-MS-H10_3cc                    PM-MER-MS-H10_3cc     Mercury
# PM-MER-MS-Rembrandt                PM-MER-MS-Rembrandt     Mercury
# PM-MER-MS-H05_3cc                    PM-MER-MS-H05_3cc     Mercury
# PM-MER-C-Beethoven                  PM-MER-C-Beethoven     Mercury
# PM-MOO-MS-Apollo11                  PM-MOO-MS-Apollo11        Moon
# PM-MOO-C-SPAA1_SU                    PM-MOO-C-SPAA1_SU        Moon
# PM-MOO-GS-SPAApollo_Detail  PM-MOO-GS-SPAApollo_Detail        Moon
# PM-MOO-C-SPAApollo                  PM-MOO-C-SPAApollo        Moon
# PM-MOO-C-SPAApollo_SU            PM-MOO-C-SPAApollo_SU        Moon
# PM-MOO-MS-Apollo12                  PM-MOO-MS-Apollo12        Moon
# PM-MOO-MS-SPAApollo                PM-MOO-MS-SPAApollo        Moon
# PM-MOO-D-YutuGPR                      PM-MOO-D-YutuGPR        Moon
# PM-MOO-MS-Copernicus              PM-MOO-MS-Copernicus        Moon
#
#                                                                  Title of map  \
# PM-MAR-MS-Crommelin              Geological Map of the Crommelin Crater, Mars
# PM-MAR-C-Crommelin          Spectral Map to highlight color or composition...
# PM-MAR-D-Oxia_Planum                  SIG and 3D data of the Oxia Planum area
# PM-MAR-D-Crommelin          3D subsurface geomodel of western Crommelin cr...
# PM-MAR-MS-Arsinoes          Geological Map of Arsinoes and Pyrrhae Chaos, ...
# PM-MAR-SI-Crommelin         Geo-stratigraphic map of NW sector of the Crom...
# PM-MAR-D-Gale_Murray                              Digital Outcrop Model (DOM)
# PM-MAR-C-Arsinoes                         Hydrated minerals in Arsinoes Chaos
# PM-MAR-D-Jezero                            SIG and 3D data of the Jezero area
# PM-MAR-D-Gale_Kimberley                       3D Models of the Kimberley area
# PM-MER-C-H05_SU                                        H05 Spectral units map
# PM-MER-GS-Rachmaninoff_5cc  "Geostratigraphic map of Rachmaninoff crater a...
# PM-MER-MS-Beethoven                        Geological maps of Beethoven Basin
# PM-MER-MS-H14_5cc           5 Class Geological Map of H-14 (The Debussy Qu...
# PM-MER-MS-H10_5cc           Geological map of the Derain (H10) quadrangle,...
# PM-MER-SI-Rembrandt              Geologic Map of the Rembrandt basin, Mercury
# PM-MER-MS-H05_5cc           Geological map of the Hokusai Quadrangle (H05)...
# PM-MER-D-Rembrandt          3D geomodel of Rembrandt structures and basin ...
# PM-MER-C-Rembrandt          "Spectral indices map of the Rembrandt basin, ...
# PM-MER-MS-Lermontov             Geologic Map of the Lermontov crater, Mercury
# PM-MER-MS-H14_3cc           3 Class Geological Map of H-14 (The Debussy Qu...
# PM-MER-C-H05                         H05-8 color and spectral indices mosaics
# PM-MER-MS-H02_3cc           Geologic Map of the Victoria Quadrangle (H02),...
# PM-MER-MS-H10_3cc           Geological Map of the Derain (H10) Quadrangle,...
# PM-MER-MS-Rembrandt              Geologic Map of the Rembrandt basin, Mercury
# PM-MER-MS-H05_3cc           Geological map of the Hokusai Quadrangle (H05)...
# PM-MER-C-Beethoven          "Spectral indices map of the Beethoven basin, ...
# PM-MOO-MS-Apollo11
# PM-MOO-C-SPAA1_SU
# PM-MOO-GS-SPAApollo_Detail  Spectro-morphological map centered on Apollo b...
# PM-MOO-C-SPAApollo
# PM-MOO-C-SPAApollo_SU
# PM-MOO-MS-Apollo12
# PM-MOO-MS-SPAApollo            Apollo Basin, Northern South Pole-Aitken Basin
# PM-MOO-D-YutuGPR            Geological model of Yutu's GPR data on Chang'e...
# PM-MOO-MS-Copernicus                      Geological Map of Copernicus Crater
#
#                            Bounding box - Min Lat Bounding box - Max Lat  \
# PM-MAR-MS-Crommelin                       3.96993                6.22761
# PM-MAR-C-Crommelin                        3.96993                6.22761
# PM-MAR-D-Oxia_Planum                     17.34694               18.94444
# PM-MAR-D-Crommelin                        3.96993                6.22761
# PM-MAR-MS-Arsinoes                          -12.0                   -5.8
# PM-MAR-SI-Crommelin                       18.1945               7.560542
# PM-MAR-D-Gale_Murray                    -4.712214              -4.712214
# PM-MAR-C-Arsinoes                           -8.17                  -7.98
# PM-MAR-D-Jezero                            18.335               18.61472
# PM-MAR-D-Gale_Kimberley                  -4.66744               -4.61862
# PM-MER-C-H05_SU                              22.5                   65.0
# PM-MER-GS-Rachmaninoff_5cc                   22.5                  40.73
# PM-MER-MS-Beethoven                         -35.0                    0.0
# PM-MER-MS-H14_5cc                           -22.5                  -65.0
# PM-MER-MS-H10_5cc                           -22.5                   22.5
# PM-MER-SI-Rembrandt                         -51.7                  -10.0
# PM-MER-MS-H05_5cc                            22.5                   65.0
# PM-MER-D-Rembrandt                          -51.7                  -10.0
# PM-MER-C-Rembrandt                          -41.0                  -25.0
# PM-MER-MS-Lermontov                          10.0                   22.0
# PM-MER-MS-H14_3cc                           -22.5                  -65.0
# PM-MER-C-H05                                 22.5                   65.0
# PM-MER-MS-H02_3cc                            22.5                   65.0
# PM-MER-MS-H10_3cc                           -22.5                   22.5
# PM-MER-MS-Rembrandt                         -51.7                  -10.0
# PM-MER-MS-H05_3cc                            22.5                   65.0
# PM-MER-C-Beethoven                          -27.7                  -15.0
# PM-MOO-MS-Apollo11                           -8.0                   10.0
# PM-MOO-C-SPAA1_SU                           -50.0                  -30.0
# PM-MOO-GS-SPAApollo_Detail                  -39.0                  -31.0
# PM-MOO-C-SPAApollo                          -46.6                  -23.5
# PM-MOO-C-SPAApollo_SU                       -46.6                  -23.5
# PM-MOO-MS-Apollo12                           -8.0                    2.0
# PM-MOO-MS-SPAApollo                         -60.0                  -10.0
# PM-MOO-D-YutuGPR                        44.113296              44.128802
# PM-MOO-MS-Copernicus                         8.03                   11.2
#
#                            Bounding box - Min Lon (0-360)  \
# PM-MAR-MS-Crommelin                              348.8477
# PM-MAR-C-Crommelin                               348.8477
# PM-MAR-D-Oxia_Planum                             25.25278
# PM-MAR-D-Crommelin                               348.8477
# PM-MAR-MS-Arsinoes                                  329.7
# PM-MAR-SI-Crommelin                            155.894958
# PM-MAR-D-Gale_Murray                            137.35439
# PM-MAR-C-Arsinoes                                  331.53
# PM-MAR-D-Jezero                                  77.20333
# PM-MAR-D-Gale_Kimberley                         137.37318
# PM-MER-C-H05_SU                                       0.0
# PM-MER-GS-Rachmaninoff_5cc                          49.81
# PM-MER-MS-Beethoven                                 220.0
# PM-MER-MS-H14_5cc                                     0.0
# PM-MER-MS-H10_5cc                                     0.0
# PM-MER-SI-Rembrandt                                 65.75
# PM-MER-MS-H05_5cc                                     0.0
# PM-MER-D-Rembrandt                                  65.75
# PM-MER-C-Rembrandt                                   75.0
# PM-MER-MS-Lermontov                                 305.0
# PM-MER-MS-H14_3cc                                     0.0
# PM-MER-C-H05                                          0.0
# PM-MER-MS-H02_3cc                                   270.0
# PM-MER-MS-H10_3cc                                     0.0
# PM-MER-MS-Rembrandt                                 65.75
# PM-MER-MS-H05_3cc                                     0.0
# PM-MER-C-Beethoven                                  227.7
# PM-MOO-MS-Apollo11                                   14.0
# PM-MOO-C-SPAA1_SU                                   160.0
# PM-MOO-GS-SPAApollo_Detail                          199.0
# PM-MOO-C-SPAApollo                                  195.0
# PM-MOO-C-SPAApollo_SU                               195.0
# PM-MOO-MS-Apollo12                                  332.0
# PM-MOO-MS-SPAApollo                                 185.0
# PM-MOO-D-YutuGPR                               340.463123
# PM-MOO-MS-Copernicus                                -21.7
#
#                            Bounding box - Max Lon (0-360)  \
# PM-MAR-MS-Crommelin                             350.98821
# PM-MAR-C-Crommelin                              350.98821
# PM-MAR-D-Oxia_Planum                             25.68028
# PM-MAR-D-Crommelin                              350.98821
# PM-MAR-MS-Arsinoes                                  334.5
# PM-MAR-SI-Crommelin                            357.867708
# PM-MAR-D-Gale_Murray                            137.35439
# PM-MAR-C-Arsinoes                                 331.758
# PM-MAR-D-Jezero                                  77.54167
# PM-MAR-D-Gale_Kimberley                         137.41877
# PM-MER-C-H05_SU                                      90.0
# PM-MER-GS-Rachmaninoff_5cc                           69.1
# PM-MER-MS-Beethoven                                   0.0
# PM-MER-MS-H14_5cc                                    90.0
# PM-MER-MS-H10_5cc                                    72.0
# PM-MER-SI-Rembrandt                                 110.0
# PM-MER-MS-H05_5cc                                    90.0
# PM-MER-D-Rembrandt                                  110.0
# PM-MER-C-Rembrandt                                  100.0
# PM-MER-MS-Lermontov                                 317.0
# PM-MER-MS-H14_3cc                                    90.0
# PM-MER-C-H05                                         90.0
# PM-MER-MS-H02_3cc                                   360.0
# PM-MER-MS-H10_3cc                                    72.0
# PM-MER-MS-Rembrandt                                 110.0
# PM-MER-MS-H05_3cc                                    90.0
# PM-MER-C-Beethoven                                  241.8
# PM-MOO-MS-Apollo11                                   33.0
# PM-MOO-C-SPAA1_SU                                   190.0
# PM-MOO-GS-SPAApollo_Detail                          214.0
# PM-MOO-C-SPAApollo                                  220.5
# PM-MOO-C-SPAApollo_SU                               220.5
# PM-MOO-MS-Apollo12                                  342.0
# PM-MOO-MS-SPAApollo                                 235.0
# PM-MOO-D-YutuGPR                                340.49069
# PM-MOO-MS-Copernicus                                -18.5
#
#                                                                     Author(s)  \
# PM-MAR-MS-Crommelin                       D. Pesce, R. Pozzobon, M. Massironi
# PM-MAR-C-Crommelin                                                   Carli C.
# PM-MAR-D-Oxia_Planum                   G. Caravaca, S. Le Mouélic, N. Mangold
# PM-MAR-D-Crommelin                        R. Pozzobon, D. Pesce, M. Massironi
# PM-MAR-MS-Arsinoes                                       E. Luzzi, A.P. Rossi
# PM-MAR-SI-Crommelin                   G. Melchiori, M. Massironi, R. Pozzobon
# PM-MAR-D-Gale_Murray        De Toffoli, B., Pozzobon, R., Massironi, M., L...
# PM-MAR-C-Arsinoes                                                 Erica Luzzi
# PM-MAR-D-Jezero                        G. Caravaca, S. Le Mouélic, N. Mangold
# PM-MAR-D-Gale_Kimberley                G. Caravaca, S. Le Mouélic, N. Mangold
# PM-MER-C-H05_SU             Francesca Zambon, Cristian Carli, Francesca Al...
# PM-MER-GS-Rachmaninoff_5cc  Jack Wright; Francesca Zambon; Cristian Carli;...
# PM-MER-MS-Beethoven
# PM-MER-MS-H14_5cc           David L. Pegg; David A. Rothery; Matt R. Balme...
# PM-MER-MS-H10_5cc           Christopher C. Malliband; David A. Rothery; Ma...
# PM-MER-SI-Rembrandt         Andrea Semenzato; Matteo Massironi; Valentina ...
# PM-MER-MS-H05_5cc           Jack Wright; David A. Rothery; Matt R. Balme; ...
# PM-MER-D-Rembrandt                                     R. Pozzobon, L. Penasa
# PM-MER-C-Rembrandt          francesca.zambon cristian.carli francesca.altieri
# PM-MER-MS-Lermontov
# PM-MER-MS-H14_3cc           David L. Pegg; David A. Rothery; Matt R. Balme...
# PM-MER-C-H05                Francesca Zambon, Cristian Carli, Francesca Al...
# PM-MER-MS-H02_3cc           Valentina Galluzzi; Laura Guzzetta; Luigi Ferr...
# PM-MER-MS-H10_3cc           Christopher C. Malliband; David A. Rothery; Ma...
# PM-MER-MS-Rembrandt         Andrea Semenzato; Matteo Massironi; Valentina ...
# PM-MER-MS-H05_3cc           Jack Wright; David A. Rothery; Matt R. Balme; ...
# PM-MER-C-Beethoven          francesca.zambon cristian.carli francesca.altieri
# PM-MOO-MS-Apollo11
# PM-MOO-C-SPAA1_SU           Francesca Zambon, Cristian Carli, Francesca Al...
# PM-MOO-GS-SPAApollo_Detail  C. Poehler, C. H. van der Bogert, H. Hiesinger...
# PM-MOO-C-SPAApollo                      Francesca Zambon, Cristian Carli, ...
# PM-MOO-C-SPAApollo_SU       Francesca Zambon, Cristian Carli, Francesca Al...
# PM-MOO-MS-Apollo12
# PM-MOO-MS-SPAApollo         Ivanov M. A., H. Hiesinger, C. H. van der Boge...
# PM-MOO-D-YutuGPR                         L. Penasa, R. Pozzobon, M. Massironi
# PM-MOO-MS-Copernicus        Filippo Tusberti, Riccardo Pozzobon Matteo Mas...
#
#                                               Type          Output scale  \
# PM-MAR-MS-Crommelin                    Preliminary             1:160.000
# PM-MAR-C-Crommelin                     Preliminary     Publication scale
# PM-MAR-D-Oxia_Planum                         Final               Dynamic
# PM-MAR-D-Crommelin                     Preliminary             1:160.000
# PM-MAR-MS-Arsinoes                     Preliminary           1:3.000.000
# PM-MAR-SI-Crommelin                       Released              1:100000
# PM-MAR-D-Gale_Murray                   Preliminary
# PM-MAR-C-Arsinoes                      Preliminary
# PM-MAR-D-Jezero                              Final               Dynamic
# PM-MAR-D-Gale_Kimberley                      Final               Dynamic
# PM-MER-C-H05_SU                    "GeoTiff, Envi"              450 m/px
# PM-MER-GS-Rachmaninoff_5cc   "GeoTiff, Envi, ISIS"                "1:3M"
# PM-MER-MS-Beethoven
# PM-MER-MS-H14_5cc                      Preliminary                  1:3M
# PM-MER-MS-H10_5cc                      Preliminary                  1:3M
# PM-MER-SI-Rembrandt          Preliminary, Released     Publication scale
# PM-MER-MS-H05_5cc            Submitted (in review)                  1:3M
# PM-MER-D-Rembrandt           Preliminary, Released     Publication scale
# PM-MER-C-Rembrandt           "GeoTiff, Envi, ISIS"              630 m/px
# PM-MER-MS-Lermontov
# PM-MER-MS-H14_3cc                      Preliminary                  1:3M
# PM-MER-C-H05                       "GeoTiff, Envi"              450 m/px
# PM-MER-MS-H02_3cc                         Released                  1:3M
# PM-MER-MS-H10_3cc                      Preliminary                  1:3M
# PM-MER-MS-Rembrandt          Preliminary, Released     Publication scale
# PM-MER-MS-H05_3cc            Submitted (in review)                  1:3M
# PM-MER-C-Beethoven           "GeoTiff, Envi, ISIS"  "450 m/px, 750 m/px"
# PM-MOO-MS-Apollo11
# PM-MOO-C-SPAA1_SU                     PDF, GeoTiff
# PM-MOO-GS-SPAApollo_Detail  Preliminary, Embargoed
# PM-MOO-C-SPAApollo
# PM-MOO-C-SPAApollo_SU                 PDF, GeoTiff
# PM-MOO-MS-Apollo12
# PM-MOO-MS-SPAApollo                      Published              1:500000
# PM-MOO-D-YutuGPR                       Preliminary
# PM-MOO-MS-Copernicus         Preliminary, Released             1:400.000
#
#                                          Original Coordinate Reference System  \
# PM-MAR-MS-Crommelin         Projected Coordinate System: Equirectangular P...
# PM-MAR-C-Crommelin                                                 CRS ???TBC
# PM-MAR-D-Oxia_Planum        Projected Coordinate System: Equirectangular_M...
# PM-MAR-D-Crommelin          Projected Coordinate System: Equirectangular; ...
# PM-MAR-MS-Arsinoes          Projected Coordinate System: Equirectangular P...
# PM-MAR-SI-Crommelin                                      Mars Equirectangular
# PM-MAR-D-Gale_Murray
# PM-MAR-C-Arsinoes
# PM-MAR-D-Jezero             Projected Coordinate System: Equirectangular_M...
# PM-MAR-D-Gale_Kimberley     Projected Coordinate System: Mars2000_Simp_sph...
# PM-MER-C-H05_SU             "Lambert conformal conic, Center longitude: 45...
# PM-MER-GS-Rachmaninoff_5cc  "Lambert conformal conic, Center longitude: 45...
# PM-MER-MS-Beethoven
# PM-MER-MS-H14_5cc           "Lambert conformal conic, Center longitude: 45...
# PM-MER-MS-H10_5cc           Mercator Center longitude: 36°E Standard paral...
# PM-MER-SI-Rembrandt         Lambert Conformal ConicCenter longitude: 87Â°E...
# PM-MER-MS-H05_5cc           Lambert conformal conicCenter longitude: 45°ES...
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt          "Equirectangular, Center longitude: 87.5°E, Ce...
# PM-MER-MS-Lermontov
# PM-MER-MS-H14_3cc           "Lambert conformal conic, Center longitude: 45...
# PM-MER-C-H05                "Lambert conformal conic, Center longitude: 45...
# PM-MER-MS-H02_3cc           Lambert conformal conicCenter longitude: 315°S...
# PM-MER-MS-H10_3cc           Mercator Center longitude: 36°E Standard paral...
# PM-MER-MS-Rembrandt         Lambert Conformal ConicCenter longitude: 87°ES...
# PM-MER-MS-H05_3cc           Lambert conformal conicCenter longitude: 45°ES...
# PM-MER-C-Beethoven          "Equirectangular, Center longitude: 124.5Â°E, ...
# PM-MOO-MS-Apollo11
# PM-MOO-C-SPAA1_SU           Simple Cylindrical, Center longitude: 207.75°E...
# PM-MOO-GS-SPAApollo_Detail                                           GCS_Moon
# PM-MOO-C-SPAApollo          Simple CylindricalCenter longitude: 207.75°ECe...
# PM-MOO-C-SPAApollo_SU       Simple Cylindrical, Center longitude: 207.75°E...
# PM-MOO-MS-Apollo12
# PM-MOO-MS-SPAApollo                                                       CRS
# PM-MOO-D-YutuGPR            Cartography: +proj=eqc +lat_ts=44 +lat_0=0 +lo...
# PM-MOO-MS-Copernicus                       GCS Moon (R: 1737400)Datum: D_moon
#
#                                                                     Data used  \
# PM-MAR-MS-Crommelin         MOLA Elevation Model MEGDR (463 m/pixel)HRSC s...
# PM-MAR-C-Crommelin                  CRISM images TRR3 (FRT, FRS, HRS and HRL)
# PM-MAR-D-Oxia_Planum        DEM from: CTX DTM (18 m)\tImagery (visible): C...
# PM-MAR-D-Crommelin          Merged DEM from: MOLA Elevation Model MEGDR (4...
# PM-MAR-MS-Arsinoes          MOLA Elevation Model MEGDR (463 m/pixel)CTX mo...
# PM-MAR-SI-Crommelin                                                CTX, CRISM
# PM-MAR-D-Gale_Murray                                    MSL Curiosity MASTCAM
# PM-MAR-C-Arsinoes                                                       CRISM
# PM-MAR-D-Jezero             DEM from: MOLA Elevation Model MEGDR (100 m/pi...
# PM-MAR-D-Gale_Kimberley     DEM from: MOLA Elevation Model MEGDR (100 m/pi...
# PM-MER-C-H05_SU                       "Spectral parameters delivered in D4.2"
# PM-MER-GS-Rachmaninoff_5cc  "MESSENGER MDIS BDR v0 uncontrolled basemap (1...
# PM-MER-MS-Beethoven
# PM-MER-MS-H14_5cc           MESSENGER MDIS BDR v1 (166 m/pixel), MESSENGER...
# PM-MER-MS-H10_5cc           MESSENGER MDIS BDR v1 (166 m/pixel), MESSENGER...
# PM-MER-SI-Rembrandt         MESSENGER MDIS BDR (v1) (166m/pixel)MESSENGER ...
# PM-MER-MS-H05_5cc           MESSENGER MDIS BDR v0 uncontrolled basemap (16...
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt           "MDIS-WAC data, filters: F, C, D, E, G, I, L, J"
# PM-MER-MS-Lermontov
# PM-MER-MS-H14_3cc           MESSENGER MDIS BDR v1 (166 m/pixel), MESSENGER...
# PM-MER-C-H05                   MDIS-WAC data, filters: F, C, D, E, G, I, L, J
# PM-MER-MS-H02_3cc           MESSENGER MDIS BDR v0 uncontrolled basemap (16...
# PM-MER-MS-H10_3cc           MESSENGER MDIS BDR v1 (166 m/pixel), MESSENGER...
# PM-MER-MS-Rembrandt         MESSENGER MDIS BDR (v1) (166m/pixel)MESSENGER ...
# PM-MER-MS-H05_3cc           MESSENGER MDIS BDR v0 uncontrolled basemap (16...
# PM-MER-C-Beethoven           "MDIS-WAC data, filters: F, C, D, E, G, I, L, J"
# PM-MOO-MS-Apollo11
# PM-MOO-C-SPAA1_SU                                    33 M3 hyperspectral data
# PM-MOO-GS-SPAApollo_Detail              Spectral parameters delivered in D4.3
# PM-MOO-C-SPAApollo                                   39 M3 hyperspectral data
# PM-MOO-C-SPAApollo_SU                                33 M3 hyperspectral data
# PM-MOO-MS-Apollo12
# PM-MOO-MS-SPAApollo         Lunar Reconnaissance Orbiter Wide Angle Camera...
# PM-MOO-D-YutuGPR            Xiao et al,  2015 figures, LROC NAC DEM and or...
# PM-MOO-MS-Copernicus        LROC-WAC (100m/p) LROC-NAC (0.5m/p) LRO LOLA &...
#
#                                                          Standards adhered to  \
# PM-MAR-MS-Crommelin         Mapping scale: Tobler (1987), Planmap mapping ...
# PM-MAR-C-Crommelin                                                        TBC
# PM-MAR-D-Oxia_Planum                                                      NaN
# PM-MAR-D-Crommelin                                                        NaN
# PM-MAR-MS-Arsinoes                         Planmap mapping standards document
# PM-MAR-SI-Crommelin                        Planmap mapping standards document
# PM-MAR-D-Gale_Murray                                                      NaN
# PM-MAR-C-Arsinoes
# PM-MAR-D-Jezero                                                           NaN
# PM-MAR-D-Gale_Kimberley                                                   NaN
# PM-MER-C-H05_SU             "\tSpectral units have been identified as desc...
# PM-MER-GS-Rachmaninoff_5cc             "Planmap mapping standards document\t"
# PM-MER-MS-Beethoven
# PM-MER-MS-H14_5cc                          Planmap mapping standards document
# PM-MER-MS-H10_5cc                          Planmap mapping standards document
# PM-MER-SI-Rembrandt                        Planmap mapping standards document
# PM-MER-MS-H05_5cc                          Planmap mapping standards document
# PM-MER-D-Rembrandt                         Planmap mapping standards document
# PM-MER-C-Rembrandt          "Data processed, as indicated by the MESSENGER...
# PM-MER-MS-Lermontov
# PM-MER-MS-H14_3cc                          Planmap mapping standards document
# PM-MER-C-H05                Data processed, as indicated by the MESSENGER ...
# PM-MER-MS-H02_3cc           Mapping scale: Tobler (1987); Output scale: US...
# PM-MER-MS-H10_3cc                          Planmap mapping standards document
# PM-MER-MS-Rembrandt                        Planmap mapping standards document
# PM-MER-MS-H05_3cc                          Planmap mapping standards document
# PM-MER-C-Beethoven          "Data processed, as indicated by the MESSENGER...
# PM-MOO-MS-Apollo11
# PM-MOO-C-SPAA1_SU                                                         NaN
# PM-MOO-GS-SPAApollo_Detail                                                NaN
# PM-MOO-C-SPAApollo
# PM-MOO-C-SPAApollo_SU                                                     NaN
# PM-MOO-MS-Apollo12
# PM-MOO-MS-SPAApollo          USGS Planetary Geologic Mapping Protocol (2018);
# PM-MOO-D-YutuGPR                                                          NaN
# PM-MOO-MS-Copernicus                       Planmap mapping standards document
#
#                                                                           DOI  \
# PM-MAR-MS-Crommelin
# PM-MAR-C-Crommelin
# PM-MAR-D-Oxia_Planum                                                      TBD
# PM-MAR-D-Crommelin
# PM-MAR-MS-Arsinoes
# PM-MAR-SI-Crommelin
# PM-MAR-D-Gale_Murray
# PM-MAR-C-Arsinoes
# PM-MAR-D-Jezero                                                           TBD
# PM-MAR-D-Gale_Kimberley                                                   TBD
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc                                                         NaN
# PM-MER-MS-H10_5cc                                                         NaN
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc           [10.1080/17445647.2019.1625821](https://doi.or...
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc                                                         NaN
# PM-MER-C-H05                                                              NaN
# PM-MER-MS-H02_3cc                               10.1080/17445647.2016.1193777
# PM-MER-MS-H10_3cc                                                         NaN
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc           [10.1080/17445647.2019.1625821](https://doi.or...
# PM-MER-C-Beethoven                                                        NaN
# PM-MOO-MS-Apollo11                                                        NaN
# PM-MOO-C-SPAA1_SU                                                 Data: Code:
# PM-MOO-GS-SPAApollo_Detail                                        Data: Code:
# PM-MOO-C-SPAApollo
# PM-MOO-C-SPAApollo_SU                                             Data: Code:
# PM-MOO-MS-Apollo12                                                        NaN
# PM-MOO-MS-SPAApollo                      https://doi.org/10.1029/2018JE005590
# PM-MOO-D-YutuGPR                                                  Data: Code:
# PM-MOO-MS-Copernicus
#
#                                                           Aims (one sentence)  \
# PM-MAR-MS-Crommelin                              Morpho-stratigraphic mapping
# PM-MAR-C-Crommelin          spectroscopical information related to spectra...
# PM-MAR-D-Oxia_Planum        GIS data of the Oxia Planum future landing sit...
# PM-MAR-D-Crommelin          3D geomodel of Crommelin Crater's inner layere...
# PM-MAR-MS-Arsinoes                               Morpho-stratigraphic mapping
# PM-MAR-SI-Crommelin         Geo-stratigraphic map of the inner layered dep...
# PM-MAR-D-Gale_Murray            Light-toned vein network structural analysis.
# PM-MAR-C-Arsinoes                                      Mineralogical analysis
# PM-MAR-D-Jezero             GIS data of the Jezero crater landing site are...
# PM-MAR-D-Gale_Kimberley     3D models and GIS data of the Kimberley area f...
# PM-MER-C-H05_SU             Definition of the spectral units map to be int...
# PM-MER-GS-Rachmaninoff_5cc  Spectromorphic analysis of Mercury's units and...
# PM-MER-MS-Beethoven
# PM-MER-MS-H14_5cc           Morpho-stratigraphic analysis of Mercury's uni...
# PM-MER-MS-H10_5cc           Morpho-stratigraphic analysis of Mercury's uni...
# PM-MER-SI-Rembrandt         Morpho-stratigraphic analysis of the geologic ...
# PM-MER-MS-H05_5cc           Morpho-stratigraphic analysis of Mercury's uni...
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt          Spectroscopical analysis and color variation t...
# PM-MER-MS-Lermontov
# PM-MER-MS-H14_3cc           Morpho-stratigraphic analysis of Mercury's uni...
# PM-MER-C-H05                Spectroscopical analysis and color variation t...
# PM-MER-MS-H02_3cc                                                         NaN
# PM-MER-MS-H10_3cc           Morpho-stratigraphic analysis of Mercury's uni...
# PM-MER-MS-Rembrandt         Morpho-stratigraphic analysis of the geologic ...
# PM-MER-MS-H05_3cc           Morpho-stratigraphic analysis of Mercury's uni...
# PM-MER-C-Beethoven          Spectroscopical analysis and color variation t...
# PM-MOO-MS-Apollo11
# PM-MOO-C-SPAA1_SU           Spectroscopical analysis and color variation t...
# PM-MOO-GS-SPAApollo_Detail  Test the use of higher level spectroscopic dat...
# PM-MOO-C-SPAApollo          Spectroscopical analysis and color variation t...
# PM-MOO-C-SPAApollo_SU       Spectroscopical analysis and color variation t...
# PM-MOO-MS-Apollo12
# PM-MOO-MS-SPAApollo             E.g. Morphologic analysis, astronaut training
# PM-MOO-D-YutuGPR            3D geomodel of layered deposits identified by ...
# PM-MOO-MS-Copernicus        Geological mapping, possible landing site char...
#
#                                                             Short description  \
# PM-MAR-MS-Crommelin         This 1:160.000 scale map by Pesce et al. cover...
# PM-MAR-C-Crommelin
# PM-MAR-D-Oxia_Planum        Orbital data released with D5.4 related to the...
# PM-MAR-D-Crommelin          This is the 3D geomodel released within D6.1 a...
# PM-MAR-MS-Arsinoes          This map shows the contacts between the disrup...
# PM-MAR-SI-Crommelin
# PM-MAR-D-Gale_Murray        Digital Outcrop Model of the Murray formation ...
# PM-MAR-C-Arsinoes           VNIR and SWIR spectral parameters + true color...
# PM-MAR-D-Jezero             Orbital data released with D5.4 related to the...
# PM-MAR-D-Gale_Kimberley     These are orbital and ground-based data releas...
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc           Mercury’s Debussy Quadrangle (H14) lies betwee...
# PM-MER-MS-H10_5cc           Mercury’s Derain (H10) quadrangle is located b...
# PM-MER-SI-Rembrandt         The ~715-km-diameter Rembrandt basin is known ...
# PM-MER-MS-H05_5cc           The Hokusai (H05) quadrangle is in Mercury’s m...
# PM-MER-D-Rembrandt          The ~715-km-diameter Rembrandt basin is known ...
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc           Mercury’s Debussy Quadrangle (H14) lies betwee...
# PM-MER-C-H05                                                              NaN
# PM-MER-MS-H02_3cc           Mercury’s quadrangle H02 ‘Victoria’ is located...
# PM-MER-MS-H10_3cc           Mercury’s Derain (H10) quadrangle is located b...
# PM-MER-MS-Rembrandt         The ~715-km-diameter Rembrandt basin is known ...
# PM-MER-MS-H05_3cc           The Hokusai (H05) quadrangle is in Mercury’s m...
# PM-MER-C-Beethoven                                                        NaN
# PM-MOO-MS-Apollo11                                                        NaN
# PM-MOO-C-SPAA1_SU
# PM-MOO-GS-SPAApollo_Detail  We vectorized the spectral units defined by PM...
# PM-MOO-C-SPAApollo
# PM-MOO-C-SPAApollo_SU
# PM-MOO-MS-Apollo12                                                        NaN
# PM-MOO-MS-SPAApollo         Geologic map of the northern portion of the So...
# PM-MOO-D-YutuGPR            This deliverable\tprovides the outputs of the ...
# PM-MOO-MS-Copernicus        Copernicus is a Moon complex crater of about 9...
#
#                            Related products (cross link to other Planmap products)  \
# PM-MAR-MS-Crommelin
# PM-MAR-C-Crommelin
# PM-MAR-D-Oxia_Planum        Deliverable 5.4 (Virtual Reality application)\...
# PM-MAR-D-Crommelin          Deliverable D2.2 (morphostratigraphic maps); D...
# PM-MAR-MS-Arsinoes
# PM-MAR-SI-Crommelin             PM-MAR-MS-Crommelin_01, PM-MAR-D-Crommelin_01
# PM-MAR-D-Gale_Murray
# PM-MAR-C-Arsinoes
# PM-MAR-D-Jezero             Deliverable 5.4 (Virtual Reality application)\...
# PM-MAR-D-Gale_Kimberley     Deliverable 5.1 (merged dataset)\tDeliverable ...
# PM-MER-C-H05_SU
# PM-MER-GS-Rachmaninoff_5cc
# PM-MER-MS-Beethoven
# PM-MER-MS-H14_5cc           Geologic Map of the Victoria Quadrangle (H02),...
# PM-MER-MS-H10_5cc           Geologic Map of the Hokusai Quadrangle (H05), ...
# PM-MER-SI-Rembrandt         Geologic Map of the Hokusai Quadrangle (H05), ...
# PM-MER-MS-H05_5cc           Geologic Map of the Victoria Quadrangle (H02),...
# PM-MER-D-Rembrandt          Geologic Map of the Hokusai Quadrangle (H05), ...
# PM-MER-C-Rembrandt          "H05-8-colors and spectral indices mosaics, co...
# PM-MER-MS-Lermontov
# PM-MER-MS-H14_3cc           Geologic Map of the Victoria Quadrangle (H02),...
# PM-MER-C-H05                Geologic Map of the Hokusai Quadrangle (H05), ...
# PM-MER-MS-H02_3cc                                                         NaN
# PM-MER-MS-H10_3cc           Geologic Map of the Hokusai Quadrangle (H05), ...
# PM-MER-MS-Rembrandt         Geologic Map of the Hokusai Quadrangle (H05), ...
# PM-MER-MS-H05_3cc           Geologic Map of the Victoria Quadrangle (H02),...
# PM-MER-C-Beethoven          "H05-8-colors and spectral indices mosaics, co...
# PM-MOO-MS-Apollo11
# PM-MOO-C-SPAA1_SU
# PM-MOO-GS-SPAApollo_Detail            PM-Moo-SU-SPAApollo, PM-MOO-MS-SPABasin
# PM-MOO-C-SPAApollo
# PM-MOO-C-SPAApollo_SU
# PM-MOO-MS-Apollo12
# PM-MOO-MS-SPAApollo         This will become linked to other SPA mapping p...
# PM-MOO-D-YutuGPR
# PM-MOO-MS-Copernicus
#
#                                                              Units Definition  \
# PM-MAR-MS-Crommelin         Aeolian deposits, AD- Very dark toned, AD1, 78...
# PM-MAR-C-Crommelin                             Units names, Codes, RGB colors
# PM-MAR-D-Oxia_Planum
# PM-MAR-D-Crommelin
# PM-MAR-MS-Arsinoes          Post-collapse craters, PCC, 51-160-44Cap Unit,...
# PM-MAR-SI-Crommelin         <ul>Aeolian Deposits: Sand and Silty deposits ...
# PM-MAR-D-Gale_Murray
# PM-MAR-C-Arsinoes
# PM-MAR-D-Jezero
# PM-MAR-D-Gale_Kimberley
# PM-MER-C-H05_SU
# PM-MER-GS-Rachmaninoff_5cc  <ul>Smooth Plains<ul> <li>sp<sup>6</sup>, 255-...
# PM-MER-MS-Beethoven
# PM-MER-MS-H14_5cc           <ul>Smooth Plains<ul><li>sp, 255-190-190</li><...
# PM-MER-MS-H10_5cc           <ul>Smooth Plains<ul><li>sp, 255-190-190</li><...
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc           Smooth Plains, sp, 255-190-190Intermediate Pla...
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        TBD
# PM-MER-MS-Lermontov
# PM-MER-MS-H14_3cc           <ul>Smooth Plains<ul><li>sp, 255-190-190</li><...
# PM-MER-C-H05
# PM-MER-MS-H02_3cc                                                         NaN
# PM-MER-MS-H10_3cc           <ul>Smooth Plains<ul><li>sp, 255-190-190</li><...
# PM-MER-MS-Rembrandt         Proximal ejecta, PE, 76-230-0Hummocky material...
# PM-MER-MS-H05_3cc           Smooth Plains, sp, 255-190-190Intermediate Pla...
# PM-MER-C-Beethoven                                                        TBD
# PM-MOO-MS-Apollo11
# PM-MOO-C-SPAA1_SU
# PM-MOO-GS-SPAApollo_Detail  <ul>Copernican Crater<ul><li>Cc_SU2</li><li>Cc...
# PM-MOO-C-SPAApollo
# PM-MOO-C-SPAApollo_SU
# PM-MOO-MS-Apollo12
# PM-MOO-MS-SPAApollo         Apl_craters_50kmApl_graben, 1 px line, (0, 0, ...
# PM-MOO-D-YutuGPR
# PM-MOO-MS-Copernicus        SURROUNDING TERRAINS, Tt, 255-235-175VOLCANIC ...
#
#                            Stratigraphic info (e.g. production function used)  \
# PM-MAR-MS-Crommelin
# PM-MAR-C-Crommelin
# PM-MAR-D-Oxia_Planum
# PM-MAR-D-Crommelin
# PM-MAR-MS-Arsinoes
# PM-MAR-SI-Crommelin
# PM-MAR-D-Gale_Murray
# PM-MAR-C-Arsinoes
# PM-MAR-D-Jezero
# PM-MAR-D-Gale_Kimberley
# PM-MER-C-H05_SU
# PM-MER-GS-Rachmaninoff_5cc
# PM-MER-MS-Beethoven
# PM-MER-MS-H14_5cc
# PM-MER-MS-H10_5cc
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt
# PM-MER-MS-Lermontov
# PM-MER-MS-H14_3cc
# PM-MER-C-H05
# PM-MER-MS-H02_3cc                                                         NaN
# PM-MER-MS-H10_3cc
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc
# PM-MER-C-Beethoven
# PM-MOO-MS-Apollo11
# PM-MOO-C-SPAA1_SU
# PM-MOO-GS-SPAApollo_Detail
# PM-MOO-C-SPAApollo
# PM-MOO-C-SPAApollo_SU
# PM-MOO-MS-Apollo12
# PM-MOO-MS-SPAApollo                                      Neukum et al. (2001)
# PM-MOO-D-YutuGPR
# PM-MOO-MS-Copernicus
#
#                            Other comments (reviewer comments, notes on post-processing)  \
# PM-MAR-MS-Crommelin
# PM-MAR-C-Crommelin          Upper Left  (10008396.577,  369139.888) ( 11d ...
# PM-MAR-D-Oxia_Planum
# PM-MAR-D-Crommelin
# PM-MAR-MS-Arsinoes
# PM-MAR-SI-Crommelin
# PM-MAR-D-Gale_Murray
# PM-MAR-C-Arsinoes
# PM-MAR-D-Jezero
# PM-MAR-D-Gale_Kimberley
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc                                                         NaN
# PM-MER-MS-H10_5cc                                                         NaN
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc                          <Links to J. Maps review comments>
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc                                                         NaN
# PM-MER-C-H05                                                              NaN
# ...
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc                                                         NaN
# PM-MER-C-Beethoven                                                        NaN
# PM-MOO-MS-Apollo11                                                        NaN
# PM-MOO-C-SPAA1_SU                                                         NaN
# PM-MOO-GS-SPAApollo_Detail                                                NaN
# PM-MOO-C-SPAApollo                                                        NaN
# PM-MOO-C-SPAApollo_SU                                                     NaN
# PM-MOO-MS-Apollo12                                                        NaN
# PM-MOO-MS-SPAApollo                                                       NaN
# PM-MOO-D-YutuGPR                                                          NaN
# PM-MOO-MS-Copernicus                                                      NaN
#
#                                                              Related products  \
# PM-MAR-MS-Crommelin                                                       NaN
# PM-MAR-C-Crommelin                                                        NaN
# PM-MAR-D-Oxia_Planum                                                      NaN
# PM-MAR-D-Crommelin                                                        NaN
# PM-MAR-MS-Arsinoes                                                        NaN
# PM-MAR-SI-Crommelin                                                       NaN
# PM-MAR-D-Gale_Murray                                                      NaN
# PM-MAR-C-Arsinoes                                                         NaN
# PM-MAR-D-Jezero                                                           NaN
# PM-MAR-D-Gale_Kimberley                                                   NaN
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc                                                         NaN
# PM-MER-MS-H10_5cc                                                         NaN
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc                                                         NaN
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc                                                         NaN
# PM-MER-C-H05                                                              NaN
# PM-MER-MS-H02_3cc           Geologic Map of the Hokusai Quadrangle (H05), ...
# PM-MER-MS-H10_3cc                                                         NaN
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc                                                         NaN
# PM-MER-C-Beethoven                                                        NaN
# PM-MOO-MS-Apollo11                                                        NaN
# PM-MOO-C-SPAA1_SU                                                         NaN
# PM-MOO-GS-SPAApollo_Detail                                                NaN
# PM-MOO-C-SPAApollo                                                        NaN
# PM-MOO-C-SPAApollo_SU                                                     NaN
# PM-MOO-MS-Apollo12                                                        NaN
# PM-MOO-MS-SPAApollo                                                       NaN
# PM-MOO-D-YutuGPR                                                          NaN
# PM-MOO-MS-Copernicus                                                      NaN
#
#                                            Units Definition (polygon styling)  \
# PM-MAR-MS-Crommelin                                                       NaN
# PM-MAR-C-Crommelin                                                        NaN
# PM-MAR-D-Oxia_Planum                                                      NaN
# PM-MAR-D-Crommelin                                                        NaN
# PM-MAR-MS-Arsinoes                                                        NaN
# PM-MAR-SI-Crommelin                                                       NaN
# PM-MAR-D-Gale_Murray                                                      NaN
# PM-MAR-C-Arsinoes                                                         NaN
# PM-MAR-D-Jezero                                                           NaN
# PM-MAR-D-Gale_Kimberley                                                   NaN
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc                                                         NaN
# PM-MER-MS-H10_5cc                                                         NaN
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc                                                         NaN
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc                                                         NaN
# PM-MER-C-H05                                                              NaN
# PM-MER-MS-H02_3cc           Smooth Plains, sp, 255-190-190Northern Smooth ...
# PM-MER-MS-H10_3cc                                                         NaN
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc                                                         NaN
# PM-MER-C-Beethoven                                                        NaN
# PM-MOO-MS-Apollo11                                                        NaN
# PM-MOO-C-SPAA1_SU                                                         NaN
# PM-MOO-GS-SPAApollo_Detail                                                NaN
# PM-MOO-C-SPAApollo                                                        NaN
# PM-MOO-C-SPAApollo_SU                                                     NaN
# PM-MOO-MS-Apollo12                                                        NaN
# PM-MOO-MS-SPAApollo                                                       NaN
# PM-MOO-D-YutuGPR                                                          NaN
# PM-MOO-MS-Copernicus                                                      NaN
#
#                                                            Stratigraphic info  \
# PM-MAR-MS-Crommelin                                                       NaN
# PM-MAR-C-Crommelin                                                        NaN
# PM-MAR-D-Oxia_Planum                                                      NaN
# PM-MAR-D-Crommelin                                                        NaN
# PM-MAR-MS-Arsinoes                                                        NaN
# PM-MAR-SI-Crommelin                                                       NaN
# PM-MAR-D-Gale_Murray                                                      NaN
# PM-MAR-C-Arsinoes                                                         NaN
# PM-MAR-D-Jezero                                                           NaN
# PM-MAR-D-Gale_Kimberley                                                   NaN
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc                                                         NaN
# PM-MER-MS-H10_5cc                                                         NaN
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc                                                         NaN
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc                                                         NaN
# PM-MER-C-H05                                                              NaN
# PM-MER-MS-H02_3cc           This map has an associated database of craters...
# PM-MER-MS-H10_3cc                                                         NaN
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc                                                         NaN
# PM-MER-C-Beethoven                                                        NaN
# PM-MOO-MS-Apollo11                                                        NaN
# PM-MOO-C-SPAA1_SU                                                         NaN
# PM-MOO-GS-SPAApollo_Detail                                                NaN
# PM-MOO-C-SPAApollo                                                        NaN
# PM-MOO-C-SPAApollo_SU                                                     NaN
# PM-MOO-MS-Apollo12                                                        NaN
# PM-MOO-MS-SPAApollo                                                       NaN
# PM-MOO-D-YutuGPR                                                          NaN
# PM-MOO-MS-Copernicus                                                      NaN
#
#                                                                Other comments  \
# PM-MAR-MS-Crommelin                                                       NaN
# PM-MAR-C-Crommelin                                                        NaN
# PM-MAR-D-Oxia_Planum                                                      NaN
# PM-MAR-D-Crommelin                                                        NaN
# PM-MAR-MS-Arsinoes                                                        NaN
# PM-MAR-SI-Crommelin                                                       NaN
# PM-MAR-D-Gale_Murray                                                      NaN
# PM-MAR-C-Arsinoes                                                         NaN
# PM-MAR-D-Jezero                                                           NaN
# PM-MAR-D-Gale_Kimberley                                                   NaN
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc                                                         NaN
# PM-MER-MS-H10_5cc                                                         NaN
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc                                                         NaN
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc                                                         NaN
# PM-MER-C-H05                                                              NaN
# PM-MER-MS-H02_3cc           Since the mapping scale (~1:400k) was much hig...
# PM-MER-MS-H10_3cc                                                         NaN
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc                                                         NaN
# PM-MER-C-Beethoven                                                        NaN
# PM-MOO-MS-Apollo11                                                        NaN
# PM-MOO-C-SPAA1_SU                                                         NaN
# PM-MOO-GS-SPAApollo_Detail                                                NaN
# PM-MOO-C-SPAApollo                                                        NaN
# PM-MOO-C-SPAApollo_SU                                                     NaN
# PM-MOO-MS-Apollo12                                                        NaN
# PM-MOO-MS-SPAApollo                                                       NaN
# PM-MOO-D-YutuGPR                                                          NaN
# PM-MOO-MS-Copernicus                                                      NaN
#
#                                                                     Standards
# PM-MAR-MS-Crommelin                                                       NaN
# PM-MAR-C-Crommelin                                                        NaN
# PM-MAR-D-Oxia_Planum                                                      NaN
# PM-MAR-D-Crommelin                                                        NaN
# PM-MAR-MS-Arsinoes                                                        NaN
# PM-MAR-SI-Crommelin                                                       NaN
# PM-MAR-D-Gale_Murray                                                      NaN
# PM-MAR-C-Arsinoes                                                         NaN
# PM-MAR-D-Jezero                                                           NaN
# PM-MAR-D-Gale_Kimberley                                                   NaN
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc                                                         NaN
# PM-MER-MS-H10_5cc                                                         NaN
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc                                                         NaN
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc                                                         NaN
# PM-MER-C-H05                                                              NaN
# PM-MER-MS-H02_3cc                                                         NaN
# PM-MER-MS-H10_3cc                                                         NaN
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc                                                         NaN
# PM-MER-C-Beethoven                                                        NaN
# PM-MOO-MS-Apollo11                                                        NaN
# PM-MOO-C-SPAA1_SU
# PM-MOO-GS-SPAApollo_Detail
# PM-MOO-C-SPAApollo                                                        NaN
# PM-MOO-C-SPAApollo_SU
# PM-MOO-MS-Apollo12                                                        NaN
# PM-MOO-MS-SPAApollo                                                       NaN
# PM-MOO-D-YutuGPR            adhered to open formats for 3D mesh, materials...
# PM-MOO-MS-Copernicus                                                      NaN

# %%
# Let's "fix" a couple of details:
# * Column names:
#   - 'Aims (one sentence)' -> 'Aims'
#   - 'Related products (cross link to other Planmap products)' -> 'Related products'
#   - 'Units Definition (polygon styling)' -> 'Units definition'
#   - 'Other comments (reviewer comments, notes on post-processing)' -> 'Other comments'
#   - 'Stratigraphic info (e.g. production function used)' -> 'Stratigraphic info'
#   - 'Standards adhered to' -> 'Standards'

mappings = {
    'Aims (one sentence)': 'Aims',
    'Related products (cross link to other Planmap products)': 'Related products',
    'Units Definition (polygon styling)': 'Units Definition',
    'Other comments (reviewer comments, notes on post-processing)': 'Other comments',
    'Stratigraphic info (e.g. production function used)': 'Stratigraphic info',
    'Standards adhered to': 'Standards'
}

def map_columns(table_all, mappings):
    """
    Return new dict/json with mappings applied
    """
    new_all = {}
    for name, table in table_all.items():
        new_table = {}
        for field, value in table.items():
            if isinstance(value, str):
                if any([ value.lower() == na for na in ('na','nan','n/a') ]) or value.strip() == '':
                    value = None
            if isinstance(value, float) and value != value:
                value = None
                
            if field in mappings:
                field = mappings[field]
                
            new_table[field] = value
            
        new_all[name] = new_table
    
    return new_all

# %%
table_tmp = map_columns(table_all, mappings)

df_tmp = pd.DataFrame(table_tmp.values(), index=table_tmp.keys())
# df_tmp

# %% [markdown]
# > We now check the column-values to confirm the mapping worked fine. And then, remove the old columns

# %%
# Check if "Map name" and the index (from directory name) have the same value
#
from IPython.display import display

pmid_column = 'Map name (PM_ID)'

if sum(names_checked := df_tmp.index != df_tmp[pmid_column]):
    print("Packages with directory (index) & 'PM_ID' not maching:\n")
    display(df_tmp.loc[names_checked][pmid_column])
else:
    print("PM_ID & Index check equal. 'PM_ID' can subtitute index.")
    # df_tmp.set_index(pmid_column, drop=True, inplace=True)
# Out:
# PM_ID & Index check equal. 'PM_ID' can subtitute index.

# %%
# Parse authors column
#

authors_column = 'Author(s)'

authors = df_tmp[authors_column].apply(lambda names: 
                                       [n.strip() for n in names.replace(' and ','').replace(',',';').split(';')] 
                                       if names else None)
df_tmp[authors_column] = authors

# %%
# df_tmp[authors_column] != None
# df_tmp = df_tmp.loc[df_tmp[authors_column] != None]
df_tmp
# Out:
#                                       Map name (PM_ID) Target body  \
# PM-MAR-MS-Crommelin                PM-MAR-MS-Crommelin        Mars
# PM-MAR-C-Crommelin                  PM-MAR-C-Crommelin        Mars
# PM-MAR-D-Oxia_Planum              PM-MAR-D-Oxia_Planum        Mars
# PM-MAR-D-Crommelin                  PM-MAR-D-Crommelin        Mars
# PM-MAR-MS-Arsinoes                  PM-MAR-MS-Arsinoes        Mars
# PM-MAR-SI-Crommelin                PM-MAR-SI-Crommelin        Mars
# PM-MAR-D-Gale_Murray              PM-MAR-D-Gale_Murray        Mars
# PM-MAR-C-Arsinoes                    PM-MAR-C-Arsinoes        Mars
# PM-MAR-D-Jezero                        PM-MAR-D-Jezero        Mars
# PM-MAR-D-Gale_Kimberley        PM-MAR-D-Gale_Kimberley        Mars
# PM-MER-C-H05_SU                        PM-MER-C-H05_SU     Mercury
# PM-MER-GS-Rachmaninoff_5cc  PM-MER-GS-Rachmaninoff_5cc     Mercury
# PM-MER-MS-Beethoven                PM-MER-MS-Beethoven     Mercury
# PM-MER-MS-H14_5cc                    PM-MER-MS-H14_5cc     Mercury
# PM-MER-MS-H10_5cc                    PM-MER-MS-H10_5cc     Mercury
# PM-MER-SI-Rembrandt                PM-MER-SI-Rembrandt     Mercury
# PM-MER-MS-H05_5cc                    PM-MER-MS-H05_5cc     Mercury
# PM-MER-D-Rembrandt                  PM-MER-D-Rembrandt     Mercury
# PM-MER-C-Rembrandt                  PM-MER-C-Rembrandt     Mercury
# PM-MER-MS-Lermontov                PM-MER-MS-Lermontov     Mercury
# PM-MER-MS-H14_3cc                    PM-MER-MS-H14_3cc     Mercury
# PM-MER-C-H05                              PM-MER-C-H05     Mercury
# PM-MER-MS-H02_3cc                    PM-MER-MS-H02_3cc     Mercury
# PM-MER-MS-H10_3cc                    PM-MER-MS-H10_3cc     Mercury
# PM-MER-MS-Rembrandt                PM-MER-MS-Rembrandt     Mercury
# PM-MER-MS-H05_3cc                    PM-MER-MS-H05_3cc     Mercury
# PM-MER-C-Beethoven                  PM-MER-C-Beethoven     Mercury
# PM-MOO-MS-Apollo11                  PM-MOO-MS-Apollo11        Moon
# PM-MOO-C-SPAA1_SU                    PM-MOO-C-SPAA1_SU        Moon
# PM-MOO-GS-SPAApollo_Detail  PM-MOO-GS-SPAApollo_Detail        Moon
# PM-MOO-C-SPAApollo                  PM-MOO-C-SPAApollo        Moon
# PM-MOO-C-SPAApollo_SU            PM-MOO-C-SPAApollo_SU        Moon
# PM-MOO-MS-Apollo12                  PM-MOO-MS-Apollo12        Moon
# PM-MOO-MS-SPAApollo                PM-MOO-MS-SPAApollo        Moon
# PM-MOO-D-YutuGPR                      PM-MOO-D-YutuGPR        Moon
# PM-MOO-MS-Copernicus              PM-MOO-MS-Copernicus        Moon
#
#                                                                  Title of map  \
# PM-MAR-MS-Crommelin              Geological Map of the Crommelin Crater, Mars
# PM-MAR-C-Crommelin          Spectral Map to highlight color or composition...
# PM-MAR-D-Oxia_Planum                  SIG and 3D data of the Oxia Planum area
# PM-MAR-D-Crommelin          3D subsurface geomodel of western Crommelin cr...
# PM-MAR-MS-Arsinoes          Geological Map of Arsinoes and Pyrrhae Chaos, ...
# PM-MAR-SI-Crommelin         Geo-stratigraphic map of NW sector of the Crom...
# PM-MAR-D-Gale_Murray                              Digital Outcrop Model (DOM)
# PM-MAR-C-Arsinoes                         Hydrated minerals in Arsinoes Chaos
# PM-MAR-D-Jezero                            SIG and 3D data of the Jezero area
# PM-MAR-D-Gale_Kimberley                       3D Models of the Kimberley area
# PM-MER-C-H05_SU                                        H05 Spectral units map
# PM-MER-GS-Rachmaninoff_5cc  "Geostratigraphic map of Rachmaninoff crater a...
# PM-MER-MS-Beethoven                        Geological maps of Beethoven Basin
# PM-MER-MS-H14_5cc           5 Class Geological Map of H-14 (The Debussy Qu...
# PM-MER-MS-H10_5cc           Geological map of the Derain (H10) quadrangle,...
# PM-MER-SI-Rembrandt              Geologic Map of the Rembrandt basin, Mercury
# PM-MER-MS-H05_5cc           Geological map of the Hokusai Quadrangle (H05)...
# PM-MER-D-Rembrandt          3D geomodel of Rembrandt structures and basin ...
# PM-MER-C-Rembrandt          "Spectral indices map of the Rembrandt basin, ...
# PM-MER-MS-Lermontov             Geologic Map of the Lermontov crater, Mercury
# PM-MER-MS-H14_3cc           3 Class Geological Map of H-14 (The Debussy Qu...
# PM-MER-C-H05                         H05-8 color and spectral indices mosaics
# PM-MER-MS-H02_3cc           Geologic Map of the Victoria Quadrangle (H02),...
# PM-MER-MS-H10_3cc           Geological Map of the Derain (H10) Quadrangle,...
# PM-MER-MS-Rembrandt              Geologic Map of the Rembrandt basin, Mercury
# PM-MER-MS-H05_3cc           Geological map of the Hokusai Quadrangle (H05)...
# PM-MER-C-Beethoven          "Spectral indices map of the Beethoven basin, ...
# PM-MOO-MS-Apollo11                                                       None
# PM-MOO-C-SPAA1_SU                                                        None
# PM-MOO-GS-SPAApollo_Detail  Spectro-morphological map centered on Apollo b...
# PM-MOO-C-SPAApollo                                                       None
# PM-MOO-C-SPAApollo_SU                                                    None
# PM-MOO-MS-Apollo12                                                       None
# PM-MOO-MS-SPAApollo            Apollo Basin, Northern South Pole-Aitken Basin
# PM-MOO-D-YutuGPR            Geological model of Yutu's GPR data on Chang'e...
# PM-MOO-MS-Copernicus                      Geological Map of Copernicus Crater
#
#                             Bounding box - Min Lat  Bounding box - Max Lat  \
# PM-MAR-MS-Crommelin                       3.969930                6.227610
# PM-MAR-C-Crommelin                        3.969930                6.227610
# PM-MAR-D-Oxia_Planum                     17.346940               18.944440
# PM-MAR-D-Crommelin                        3.969930                6.227610
# PM-MAR-MS-Arsinoes                      -12.000000               -5.800000
# PM-MAR-SI-Crommelin                      18.194500                7.560542
# PM-MAR-D-Gale_Murray                     -4.712214               -4.712214
# PM-MAR-C-Arsinoes                        -8.170000               -7.980000
# PM-MAR-D-Jezero                          18.335000               18.614720
# PM-MAR-D-Gale_Kimberley                  -4.667440               -4.618620
# PM-MER-C-H05_SU                          22.500000               65.000000
# PM-MER-GS-Rachmaninoff_5cc               22.500000               40.730000
# PM-MER-MS-Beethoven                     -35.000000                0.000000
# PM-MER-MS-H14_5cc                       -22.500000              -65.000000
# PM-MER-MS-H10_5cc                       -22.500000               22.500000
# PM-MER-SI-Rembrandt                     -51.700000              -10.000000
# PM-MER-MS-H05_5cc                        22.500000               65.000000
# PM-MER-D-Rembrandt                      -51.700000              -10.000000
# PM-MER-C-Rembrandt                      -41.000000              -25.000000
# PM-MER-MS-Lermontov                      10.000000               22.000000
# PM-MER-MS-H14_3cc                       -22.500000              -65.000000
# PM-MER-C-H05                             22.500000               65.000000
# PM-MER-MS-H02_3cc                        22.500000               65.000000
# PM-MER-MS-H10_3cc                       -22.500000               22.500000
# PM-MER-MS-Rembrandt                     -51.700000              -10.000000
# PM-MER-MS-H05_3cc                        22.500000               65.000000
# PM-MER-C-Beethoven                      -27.700000              -15.000000
# PM-MOO-MS-Apollo11                       -8.000000               10.000000
# PM-MOO-C-SPAA1_SU                       -50.000000              -30.000000
# PM-MOO-GS-SPAApollo_Detail              -39.000000              -31.000000
# PM-MOO-C-SPAApollo                      -46.600000              -23.500000
# PM-MOO-C-SPAApollo_SU                   -46.600000              -23.500000
# PM-MOO-MS-Apollo12                       -8.000000                2.000000
# PM-MOO-MS-SPAApollo                     -60.000000              -10.000000
# PM-MOO-D-YutuGPR                         44.113296               44.128802
# PM-MOO-MS-Copernicus                      8.030000               11.200000
#
#                             Bounding box - Min Lon (0-360)  \
# PM-MAR-MS-Crommelin                             348.847700
# PM-MAR-C-Crommelin                              348.847700
# PM-MAR-D-Oxia_Planum                             25.252780
# PM-MAR-D-Crommelin                              348.847700
# PM-MAR-MS-Arsinoes                              329.700000
# PM-MAR-SI-Crommelin                             155.894958
# PM-MAR-D-Gale_Murray                            137.354390
# PM-MAR-C-Arsinoes                               331.530000
# PM-MAR-D-Jezero                                  77.203330
# PM-MAR-D-Gale_Kimberley                         137.373180
# PM-MER-C-H05_SU                                   0.000000
# PM-MER-GS-Rachmaninoff_5cc                       49.810000
# PM-MER-MS-Beethoven                             220.000000
# PM-MER-MS-H14_5cc                                 0.000000
# PM-MER-MS-H10_5cc                                 0.000000
# PM-MER-SI-Rembrandt                              65.750000
# PM-MER-MS-H05_5cc                                 0.000000
# PM-MER-D-Rembrandt                               65.750000
# PM-MER-C-Rembrandt                               75.000000
# PM-MER-MS-Lermontov                             305.000000
# PM-MER-MS-H14_3cc                                 0.000000
# PM-MER-C-H05                                      0.000000
# PM-MER-MS-H02_3cc                               270.000000
# PM-MER-MS-H10_3cc                                 0.000000
# PM-MER-MS-Rembrandt                              65.750000
# PM-MER-MS-H05_3cc                                 0.000000
# PM-MER-C-Beethoven                              227.700000
# PM-MOO-MS-Apollo11                               14.000000
# PM-MOO-C-SPAA1_SU                               160.000000
# PM-MOO-GS-SPAApollo_Detail                      199.000000
# PM-MOO-C-SPAApollo                              195.000000
# PM-MOO-C-SPAApollo_SU                           195.000000
# PM-MOO-MS-Apollo12                              332.000000
# PM-MOO-MS-SPAApollo                             185.000000
# PM-MOO-D-YutuGPR                                340.463123
# PM-MOO-MS-Copernicus                            -21.700000
#
#                             Bounding box - Max Lon (0-360)  \
# PM-MAR-MS-Crommelin                             350.988210
# PM-MAR-C-Crommelin                              350.988210
# PM-MAR-D-Oxia_Planum                             25.680280
# PM-MAR-D-Crommelin                              350.988210
# PM-MAR-MS-Arsinoes                              334.500000
# PM-MAR-SI-Crommelin                             357.867708
# PM-MAR-D-Gale_Murray                            137.354390
# PM-MAR-C-Arsinoes                               331.758000
# PM-MAR-D-Jezero                                  77.541670
# PM-MAR-D-Gale_Kimberley                         137.418770
# PM-MER-C-H05_SU                                  90.000000
# PM-MER-GS-Rachmaninoff_5cc                       69.100000
# PM-MER-MS-Beethoven                               0.000000
# PM-MER-MS-H14_5cc                                90.000000
# PM-MER-MS-H10_5cc                                72.000000
# PM-MER-SI-Rembrandt                             110.000000
# PM-MER-MS-H05_5cc                                90.000000
# PM-MER-D-Rembrandt                              110.000000
# PM-MER-C-Rembrandt                              100.000000
# PM-MER-MS-Lermontov                             317.000000
# PM-MER-MS-H14_3cc                                90.000000
# PM-MER-C-H05                                     90.000000
# PM-MER-MS-H02_3cc                               360.000000
# PM-MER-MS-H10_3cc                                72.000000
# PM-MER-MS-Rembrandt                             110.000000
# PM-MER-MS-H05_3cc                                90.000000
# PM-MER-C-Beethoven                              241.800000
# PM-MOO-MS-Apollo11                               33.000000
# PM-MOO-C-SPAA1_SU                               190.000000
# PM-MOO-GS-SPAApollo_Detail                      214.000000
# PM-MOO-C-SPAApollo                              220.500000
# PM-MOO-C-SPAApollo_SU                           220.500000
# PM-MOO-MS-Apollo12                              342.000000
# PM-MOO-MS-SPAApollo                             235.000000
# PM-MOO-D-YutuGPR                                340.490690
# PM-MOO-MS-Copernicus                            -18.500000
#
#                                                                     Author(s)  \
# PM-MAR-MS-Crommelin                     [D. Pesce, R. Pozzobon, M. Massironi]
# PM-MAR-C-Crommelin                                                 [Carli C.]
# PM-MAR-D-Oxia_Planum                 [G. Caravaca, S. Le Mouélic, N. Mangold]
# PM-MAR-D-Crommelin                      [R. Pozzobon, D. Pesce, M. Massironi]
# PM-MAR-MS-Arsinoes                                     [E. Luzzi, A.P. Rossi]
# PM-MAR-SI-Crommelin                 [G. Melchiori, M. Massironi, R. Pozzobon]
# PM-MAR-D-Gale_Murray        [De Toffoli, B., Pozzobon, R., Massironi, M., ...
# PM-MAR-C-Arsinoes                                               [Erica Luzzi]
# PM-MAR-D-Jezero                      [G. Caravaca, S. Le Mouélic, N. Mangold]
# PM-MAR-D-Gale_Kimberley              [G. Caravaca, S. Le Mouélic, N. Mangold]
# PM-MER-C-H05_SU             [Francesca Zambon, Cristian Carli, Francesca A...
# PM-MER-GS-Rachmaninoff_5cc  [Jack Wright, Francesca Zambon, Cristian Carli...
# PM-MER-MS-Beethoven                                                      None
# PM-MER-MS-H14_5cc           [David L. Pegg, David A. Rothery, Matt R. Balm...
# PM-MER-MS-H10_5cc           [Christopher C. Malliband, David A. Rothery, M...
# PM-MER-SI-Rembrandt         [Andrea Semenzato, Matteo Massironi, Valentina...
# PM-MER-MS-H05_5cc           [Jack Wright, David A. Rothery, Matt R. Balme,...
# PM-MER-D-Rembrandt                                   [R. Pozzobon, L. Penasa]
# PM-MER-C-Rembrandt          [francesca.zambon cristian.carli francesca.alt...
# PM-MER-MS-Lermontov                                                      None
# PM-MER-MS-H14_3cc           [David L. Pegg, David A. Rothery, Matt R. Balm...
# PM-MER-C-H05                [Francesca Zambon, Cristian Carli, Francesca A...
# PM-MER-MS-H02_3cc           [Valentina Galluzzi, Laura Guzzetta, Luigi Fer...
# PM-MER-MS-H10_3cc           [Christopher C. Malliband, David A. Rothery, M...
# PM-MER-MS-Rembrandt         [Andrea Semenzato, Matteo Massironi, Valentina...
# PM-MER-MS-H05_3cc           [Jack Wright, David A. Rothery, Matt R. Balme,...
# PM-MER-C-Beethoven          [francesca.zambon cristian.carli francesca.alt...
# PM-MOO-MS-Apollo11                                                       None
# PM-MOO-C-SPAA1_SU           [Francesca Zambon, Cristian Carli, Francesca A...
# PM-MOO-GS-SPAApollo_Detail  [C. Poehler, C. H. van der Bogert, H. Hiesinge...
# PM-MOO-C-SPAApollo                    [Francesca Zambon, Cristian Carli, ...]
# PM-MOO-C-SPAApollo_SU       [Francesca Zambon, Cristian Carli, Francesca A...
# PM-MOO-MS-Apollo12                                                       None
# PM-MOO-MS-SPAApollo         [Ivanov M. A., H. Hiesinger, C. H. van der Bog...
# PM-MOO-D-YutuGPR                       [L. Penasa, R. Pozzobon, M. Massironi]
# PM-MOO-MS-Copernicus        [Filippo Tusberti, Riccardo Pozzobon Matteo Ma...
#
#                                               Type          Output scale  \
# PM-MAR-MS-Crommelin                    Preliminary             1:160.000
# PM-MAR-C-Crommelin                     Preliminary     Publication scale
# PM-MAR-D-Oxia_Planum                         Final               Dynamic
# PM-MAR-D-Crommelin                     Preliminary             1:160.000
# PM-MAR-MS-Arsinoes                     Preliminary           1:3.000.000
# PM-MAR-SI-Crommelin                       Released              1:100000
# PM-MAR-D-Gale_Murray                   Preliminary                  None
# PM-MAR-C-Arsinoes                      Preliminary                  None
# PM-MAR-D-Jezero                              Final               Dynamic
# PM-MAR-D-Gale_Kimberley                      Final               Dynamic
# PM-MER-C-H05_SU                    "GeoTiff, Envi"              450 m/px
# PM-MER-GS-Rachmaninoff_5cc   "GeoTiff, Envi, ISIS"                "1:3M"
# PM-MER-MS-Beethoven                           None                  None
# PM-MER-MS-H14_5cc                      Preliminary                  1:3M
# PM-MER-MS-H10_5cc                      Preliminary                  1:3M
# PM-MER-SI-Rembrandt          Preliminary, Released     Publication scale
# PM-MER-MS-H05_5cc            Submitted (in review)                  1:3M
# PM-MER-D-Rembrandt           Preliminary, Released     Publication scale
# PM-MER-C-Rembrandt           "GeoTiff, Envi, ISIS"              630 m/px
# PM-MER-MS-Lermontov                           None                  None
# PM-MER-MS-H14_3cc                      Preliminary                  1:3M
# PM-MER-C-H05                       "GeoTiff, Envi"              450 m/px
# PM-MER-MS-H02_3cc                         Released                  1:3M
# PM-MER-MS-H10_3cc                      Preliminary                  1:3M
# PM-MER-MS-Rembrandt          Preliminary, Released     Publication scale
# PM-MER-MS-H05_3cc            Submitted (in review)                  1:3M
# PM-MER-C-Beethoven           "GeoTiff, Envi, ISIS"  "450 m/px, 750 m/px"
# PM-MOO-MS-Apollo11                            None                  None
# PM-MOO-C-SPAA1_SU                     PDF, GeoTiff                  None
# PM-MOO-GS-SPAApollo_Detail  Preliminary, Embargoed                  None
# PM-MOO-C-SPAApollo                            None                  None
# PM-MOO-C-SPAApollo_SU                 PDF, GeoTiff                  None
# PM-MOO-MS-Apollo12                            None                  None
# PM-MOO-MS-SPAApollo                      Published              1:500000
# PM-MOO-D-YutuGPR                       Preliminary                  None
# PM-MOO-MS-Copernicus         Preliminary, Released             1:400.000
#
#                                          Original Coordinate Reference System  \
# PM-MAR-MS-Crommelin         Projected Coordinate System: Equirectangular P...
# PM-MAR-C-Crommelin                                                 CRS ???TBC
# PM-MAR-D-Oxia_Planum        Projected Coordinate System: Equirectangular_M...
# PM-MAR-D-Crommelin          Projected Coordinate System: Equirectangular; ...
# PM-MAR-MS-Arsinoes          Projected Coordinate System: Equirectangular P...
# PM-MAR-SI-Crommelin                                      Mars Equirectangular
# PM-MAR-D-Gale_Murray                                                     None
# PM-MAR-C-Arsinoes                                                        None
# PM-MAR-D-Jezero             Projected Coordinate System: Equirectangular_M...
# PM-MAR-D-Gale_Kimberley     Projected Coordinate System: Mars2000_Simp_sph...
# PM-MER-C-H05_SU             "Lambert conformal conic, Center longitude: 45...
# PM-MER-GS-Rachmaninoff_5cc  "Lambert conformal conic, Center longitude: 45...
# PM-MER-MS-Beethoven                                                      None
# PM-MER-MS-H14_5cc           "Lambert conformal conic, Center longitude: 45...
# PM-MER-MS-H10_5cc           Mercator Center longitude: 36°E Standard paral...
# PM-MER-SI-Rembrandt         Lambert Conformal ConicCenter longitude: 87Â°E...
# PM-MER-MS-H05_5cc           Lambert conformal conicCenter longitude: 45°ES...
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt          "Equirectangular, Center longitude: 87.5°E, Ce...
# PM-MER-MS-Lermontov                                                      None
# PM-MER-MS-H14_3cc           "Lambert conformal conic, Center longitude: 45...
# PM-MER-C-H05                "Lambert conformal conic, Center longitude: 45...
# PM-MER-MS-H02_3cc           Lambert conformal conicCenter longitude: 315°S...
# PM-MER-MS-H10_3cc           Mercator Center longitude: 36°E Standard paral...
# PM-MER-MS-Rembrandt         Lambert Conformal ConicCenter longitude: 87°ES...
# PM-MER-MS-H05_3cc           Lambert conformal conicCenter longitude: 45°ES...
# PM-MER-C-Beethoven          "Equirectangular, Center longitude: 124.5Â°E, ...
# PM-MOO-MS-Apollo11                                                       None
# PM-MOO-C-SPAA1_SU           Simple Cylindrical, Center longitude: 207.75°E...
# PM-MOO-GS-SPAApollo_Detail                                           GCS_Moon
# PM-MOO-C-SPAApollo          Simple CylindricalCenter longitude: 207.75°ECe...
# PM-MOO-C-SPAApollo_SU       Simple Cylindrical, Center longitude: 207.75°E...
# PM-MOO-MS-Apollo12                                                       None
# PM-MOO-MS-SPAApollo                                                       CRS
# PM-MOO-D-YutuGPR            Cartography: +proj=eqc +lat_ts=44 +lat_0=0 +lo...
# PM-MOO-MS-Copernicus                       GCS Moon (R: 1737400)Datum: D_moon
#
#                                                                     Data used  \
# PM-MAR-MS-Crommelin         MOLA Elevation Model MEGDR (463 m/pixel)HRSC s...
# PM-MAR-C-Crommelin                  CRISM images TRR3 (FRT, FRS, HRS and HRL)
# PM-MAR-D-Oxia_Planum        DEM from: CTX DTM (18 m)\tImagery (visible): C...
# PM-MAR-D-Crommelin          Merged DEM from: MOLA Elevation Model MEGDR (4...
# PM-MAR-MS-Arsinoes          MOLA Elevation Model MEGDR (463 m/pixel)CTX mo...
# PM-MAR-SI-Crommelin                                                CTX, CRISM
# PM-MAR-D-Gale_Murray                                    MSL Curiosity MASTCAM
# PM-MAR-C-Arsinoes                                                       CRISM
# PM-MAR-D-Jezero             DEM from: MOLA Elevation Model MEGDR (100 m/pi...
# PM-MAR-D-Gale_Kimberley     DEM from: MOLA Elevation Model MEGDR (100 m/pi...
# PM-MER-C-H05_SU                       "Spectral parameters delivered in D4.2"
# PM-MER-GS-Rachmaninoff_5cc  "MESSENGER MDIS BDR v0 uncontrolled basemap (1...
# PM-MER-MS-Beethoven                                                      None
# PM-MER-MS-H14_5cc           MESSENGER MDIS BDR v1 (166 m/pixel), MESSENGER...
# PM-MER-MS-H10_5cc           MESSENGER MDIS BDR v1 (166 m/pixel), MESSENGER...
# PM-MER-SI-Rembrandt         MESSENGER MDIS BDR (v1) (166m/pixel)MESSENGER ...
# PM-MER-MS-H05_5cc           MESSENGER MDIS BDR v0 uncontrolled basemap (16...
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt           "MDIS-WAC data, filters: F, C, D, E, G, I, L, J"
# PM-MER-MS-Lermontov                                                      None
# PM-MER-MS-H14_3cc           MESSENGER MDIS BDR v1 (166 m/pixel), MESSENGER...
# PM-MER-C-H05                   MDIS-WAC data, filters: F, C, D, E, G, I, L, J
# PM-MER-MS-H02_3cc           MESSENGER MDIS BDR v0 uncontrolled basemap (16...
# PM-MER-MS-H10_3cc           MESSENGER MDIS BDR v1 (166 m/pixel), MESSENGER...
# PM-MER-MS-Rembrandt         MESSENGER MDIS BDR (v1) (166m/pixel)MESSENGER ...
# PM-MER-MS-H05_3cc           MESSENGER MDIS BDR v0 uncontrolled basemap (16...
# PM-MER-C-Beethoven           "MDIS-WAC data, filters: F, C, D, E, G, I, L, J"
# PM-MOO-MS-Apollo11                                                       None
# PM-MOO-C-SPAA1_SU                                    33 M3 hyperspectral data
# PM-MOO-GS-SPAApollo_Detail              Spectral parameters delivered in D4.3
# PM-MOO-C-SPAApollo                                   39 M3 hyperspectral data
# PM-MOO-C-SPAApollo_SU                                33 M3 hyperspectral data
# PM-MOO-MS-Apollo12                                                       None
# PM-MOO-MS-SPAApollo         Lunar Reconnaissance Orbiter Wide Angle Camera...
# PM-MOO-D-YutuGPR            Xiao et al,  2015 figures, LROC NAC DEM and or...
# PM-MOO-MS-Copernicus        LROC-WAC (100m/p) LROC-NAC (0.5m/p) LRO LOLA &...
#
#                                                                     Standards  \
# PM-MAR-MS-Crommelin         Mapping scale: Tobler (1987), Planmap mapping ...
# PM-MAR-C-Crommelin                                                        TBC
# PM-MAR-D-Oxia_Planum                                                      NaN
# PM-MAR-D-Crommelin                                                        NaN
# PM-MAR-MS-Arsinoes                         Planmap mapping standards document
# PM-MAR-SI-Crommelin                        Planmap mapping standards document
# PM-MAR-D-Gale_Murray                                                      NaN
# PM-MAR-C-Arsinoes                                                        None
# PM-MAR-D-Jezero                                                           NaN
# PM-MAR-D-Gale_Kimberley                                                   NaN
# PM-MER-C-H05_SU             "\tSpectral units have been identified as desc...
# PM-MER-GS-Rachmaninoff_5cc             "Planmap mapping standards document\t"
# PM-MER-MS-Beethoven                                                      None
# PM-MER-MS-H14_5cc                          Planmap mapping standards document
# PM-MER-MS-H10_5cc                          Planmap mapping standards document
# PM-MER-SI-Rembrandt                        Planmap mapping standards document
# PM-MER-MS-H05_5cc                          Planmap mapping standards document
# PM-MER-D-Rembrandt                         Planmap mapping standards document
# PM-MER-C-Rembrandt          "Data processed, as indicated by the MESSENGER...
# PM-MER-MS-Lermontov                                                      None
# PM-MER-MS-H14_3cc                          Planmap mapping standards document
# PM-MER-C-H05                Data processed, as indicated by the MESSENGER ...
# PM-MER-MS-H02_3cc           Mapping scale: Tobler (1987); Output scale: US...
# PM-MER-MS-H10_3cc                          Planmap mapping standards document
# PM-MER-MS-Rembrandt                        Planmap mapping standards document
# PM-MER-MS-H05_3cc                          Planmap mapping standards document
# PM-MER-C-Beethoven          "Data processed, as indicated by the MESSENGER...
# PM-MOO-MS-Apollo11                                                       None
# PM-MOO-C-SPAA1_SU                                                        None
# PM-MOO-GS-SPAApollo_Detail                                               None
# PM-MOO-C-SPAApollo                                                       None
# PM-MOO-C-SPAApollo_SU                                                    None
# PM-MOO-MS-Apollo12                                                       None
# PM-MOO-MS-SPAApollo          USGS Planetary Geologic Mapping Protocol (2018);
# PM-MOO-D-YutuGPR            adhered to open formats for 3D mesh, materials...
# PM-MOO-MS-Copernicus                       Planmap mapping standards document
#
#                                                                           DOI  \
# PM-MAR-MS-Crommelin                                                      None
# PM-MAR-C-Crommelin                                                       None
# PM-MAR-D-Oxia_Planum                                                      TBD
# PM-MAR-D-Crommelin                                                       None
# PM-MAR-MS-Arsinoes                                                       None
# PM-MAR-SI-Crommelin                                                      None
# PM-MAR-D-Gale_Murray                                                     None
# PM-MAR-C-Arsinoes                                                        None
# PM-MAR-D-Jezero                                                           TBD
# PM-MAR-D-Gale_Kimberley                                                   TBD
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc                                                         NaN
# PM-MER-MS-H10_5cc                                                         NaN
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc           [10.1080/17445647.2019.1625821](https://doi.or...
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc                                                         NaN
# PM-MER-C-H05                                                              NaN
# PM-MER-MS-H02_3cc                               10.1080/17445647.2016.1193777
# PM-MER-MS-H10_3cc                                                         NaN
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc           [10.1080/17445647.2019.1625821](https://doi.or...
# PM-MER-C-Beethoven                                                        NaN
# PM-MOO-MS-Apollo11                                                        NaN
# PM-MOO-C-SPAA1_SU                                                 Data: Code:
# PM-MOO-GS-SPAApollo_Detail                                        Data: Code:
# PM-MOO-C-SPAApollo                                                       None
# PM-MOO-C-SPAApollo_SU                                             Data: Code:
# PM-MOO-MS-Apollo12                                                        NaN
# PM-MOO-MS-SPAApollo                      https://doi.org/10.1029/2018JE005590
# PM-MOO-D-YutuGPR                                                  Data: Code:
# PM-MOO-MS-Copernicus                                                     None
#
#                                                                          Aims  \
# PM-MAR-MS-Crommelin                              Morpho-stratigraphic mapping
# PM-MAR-C-Crommelin          spectroscopical information related to spectra...
# PM-MAR-D-Oxia_Planum        GIS data of the Oxia Planum future landing sit...
# PM-MAR-D-Crommelin          3D geomodel of Crommelin Crater's inner layere...
# PM-MAR-MS-Arsinoes                               Morpho-stratigraphic mapping
# PM-MAR-SI-Crommelin         Geo-stratigraphic map of the inner layered dep...
# PM-MAR-D-Gale_Murray            Light-toned vein network structural analysis.
# PM-MAR-C-Arsinoes                                      Mineralogical analysis
# PM-MAR-D-Jezero             GIS data of the Jezero crater landing site are...
# PM-MAR-D-Gale_Kimberley     3D models and GIS data of the Kimberley area f...
# PM-MER-C-H05_SU             Definition of the spectral units map to be int...
# PM-MER-GS-Rachmaninoff_5cc  Spectromorphic analysis of Mercury's units and...
# PM-MER-MS-Beethoven                                                      None
# PM-MER-MS-H14_5cc           Morpho-stratigraphic analysis of Mercury's uni...
# PM-MER-MS-H10_5cc           Morpho-stratigraphic analysis of Mercury's uni...
# PM-MER-SI-Rembrandt         Morpho-stratigraphic analysis of the geologic ...
# PM-MER-MS-H05_5cc           Morpho-stratigraphic analysis of Mercury's uni...
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt          Spectroscopical analysis and color variation t...
# PM-MER-MS-Lermontov                                                      None
# PM-MER-MS-H14_3cc           Morpho-stratigraphic analysis of Mercury's uni...
# PM-MER-C-H05                Spectroscopical analysis and color variation t...
# PM-MER-MS-H02_3cc           Morpho-stratigraphic analysis of Mercury's uni...
# PM-MER-MS-H10_3cc           Morpho-stratigraphic analysis of Mercury's uni...
# PM-MER-MS-Rembrandt         Morpho-stratigraphic analysis of the geologic ...
# PM-MER-MS-H05_3cc           Morpho-stratigraphic analysis of Mercury's uni...
# PM-MER-C-Beethoven          Spectroscopical analysis and color variation t...
# PM-MOO-MS-Apollo11                                                       None
# PM-MOO-C-SPAA1_SU           Spectroscopical analysis and color variation t...
# PM-MOO-GS-SPAApollo_Detail  Test the use of higher level spectroscopic dat...
# PM-MOO-C-SPAApollo          Spectroscopical analysis and color variation t...
# PM-MOO-C-SPAApollo_SU       Spectroscopical analysis and color variation t...
# PM-MOO-MS-Apollo12                                                       None
# PM-MOO-MS-SPAApollo             E.g. Morphologic analysis, astronaut training
# PM-MOO-D-YutuGPR            3D geomodel of layered deposits identified by ...
# PM-MOO-MS-Copernicus        Geological mapping, possible landing site char...
#
#                                                             Short description  \
# PM-MAR-MS-Crommelin         This 1:160.000 scale map by Pesce et al. cover...
# PM-MAR-C-Crommelin                                                       None
# PM-MAR-D-Oxia_Planum        Orbital data released with D5.4 related to the...
# PM-MAR-D-Crommelin          This is the 3D geomodel released within D6.1 a...
# PM-MAR-MS-Arsinoes          This map shows the contacts between the disrup...
# PM-MAR-SI-Crommelin                                                      None
# PM-MAR-D-Gale_Murray        Digital Outcrop Model of the Murray formation ...
# PM-MAR-C-Arsinoes           VNIR and SWIR spectral parameters + true color...
# PM-MAR-D-Jezero             Orbital data released with D5.4 related to the...
# PM-MAR-D-Gale_Kimberley     These are orbital and ground-based data releas...
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc           Mercury’s Debussy Quadrangle (H14) lies betwee...
# PM-MER-MS-H10_5cc           Mercury’s Derain (H10) quadrangle is located b...
# PM-MER-SI-Rembrandt         The ~715-km-diameter Rembrandt basin is known ...
# PM-MER-MS-H05_5cc           The Hokusai (H05) quadrangle is in Mercury’s m...
# PM-MER-D-Rembrandt          The ~715-km-diameter Rembrandt basin is known ...
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc           Mercury’s Debussy Quadrangle (H14) lies betwee...
# PM-MER-C-H05                                                              NaN
# PM-MER-MS-H02_3cc           Mercury’s quadrangle H02 ‘Victoria’ is located...
# PM-MER-MS-H10_3cc           Mercury’s Derain (H10) quadrangle is located b...
# PM-MER-MS-Rembrandt         The ~715-km-diameter Rembrandt basin is known ...
# PM-MER-MS-H05_3cc           The Hokusai (H05) quadrangle is in Mercury’s m...
# PM-MER-C-Beethoven                                                        NaN
# PM-MOO-MS-Apollo11                                                        NaN
# PM-MOO-C-SPAA1_SU                                                        None
# PM-MOO-GS-SPAApollo_Detail  We vectorized the spectral units defined by PM...
# PM-MOO-C-SPAApollo                                                       None
# PM-MOO-C-SPAApollo_SU                                                    None
# PM-MOO-MS-Apollo12                                                        NaN
# PM-MOO-MS-SPAApollo         Geologic map of the northern portion of the So...
# PM-MOO-D-YutuGPR            This deliverable\tprovides the outputs of the ...
# PM-MOO-MS-Copernicus        Copernicus is a Moon complex crater of about 9...
#
#                                                              Related products  \
# PM-MAR-MS-Crommelin                                                      None
# PM-MAR-C-Crommelin                                                       None
# PM-MAR-D-Oxia_Planum        Deliverable 5.4 (Virtual Reality application)\...
# PM-MAR-D-Crommelin          Deliverable D2.2 (morphostratigraphic maps); D...
# PM-MAR-MS-Arsinoes                                                       None
# PM-MAR-SI-Crommelin             PM-MAR-MS-Crommelin_01, PM-MAR-D-Crommelin_01
# PM-MAR-D-Gale_Murray                                                     None
# PM-MAR-C-Arsinoes                                                        None
# PM-MAR-D-Jezero             Deliverable 5.4 (Virtual Reality application)\...
# PM-MAR-D-Gale_Kimberley     Deliverable 5.1 (merged dataset)\tDeliverable ...
# PM-MER-C-H05_SU                                                          None
# PM-MER-GS-Rachmaninoff_5cc                                               None
# PM-MER-MS-Beethoven                                                      None
# PM-MER-MS-H14_5cc           Geologic Map of the Victoria Quadrangle (H02),...
# PM-MER-MS-H10_5cc           Geologic Map of the Hokusai Quadrangle (H05), ...
# PM-MER-SI-Rembrandt         Geologic Map of the Hokusai Quadrangle (H05), ...
# PM-MER-MS-H05_5cc           Geologic Map of the Victoria Quadrangle (H02),...
# PM-MER-D-Rembrandt          Geologic Map of the Hokusai Quadrangle (H05), ...
# PM-MER-C-Rembrandt          "H05-8-colors and spectral indices mosaics, co...
# PM-MER-MS-Lermontov                                                      None
# PM-MER-MS-H14_3cc           Geologic Map of the Victoria Quadrangle (H02),...
# PM-MER-C-H05                Geologic Map of the Hokusai Quadrangle (H05), ...
# PM-MER-MS-H02_3cc           Geologic Map of the Hokusai Quadrangle (H05), ...
# PM-MER-MS-H10_3cc           Geologic Map of the Hokusai Quadrangle (H05), ...
# PM-MER-MS-Rembrandt         Geologic Map of the Hokusai Quadrangle (H05), ...
# PM-MER-MS-H05_3cc           Geologic Map of the Victoria Quadrangle (H02),...
# PM-MER-C-Beethoven          "H05-8-colors and spectral indices mosaics, co...
# PM-MOO-MS-Apollo11                                                       None
# PM-MOO-C-SPAA1_SU                                                        None
# PM-MOO-GS-SPAApollo_Detail            PM-Moo-SU-SPAApollo, PM-MOO-MS-SPABasin
# PM-MOO-C-SPAApollo                                                       None
# PM-MOO-C-SPAApollo_SU                                                    None
# PM-MOO-MS-Apollo12                                                       None
# PM-MOO-MS-SPAApollo         This will become linked to other SPA mapping p...
# PM-MOO-D-YutuGPR                                                         None
# PM-MOO-MS-Copernicus                                                     None
#
#                                                              Units Definition  \
# PM-MAR-MS-Crommelin         Aeolian deposits, AD- Very dark toned, AD1, 78...
# PM-MAR-C-Crommelin                             Units names, Codes, RGB colors
# PM-MAR-D-Oxia_Planum                                                     None
# PM-MAR-D-Crommelin                                                       None
# PM-MAR-MS-Arsinoes          Post-collapse craters, PCC, 51-160-44Cap Unit,...
# PM-MAR-SI-Crommelin         <ul>Aeolian Deposits: Sand and Silty deposits ...
# PM-MAR-D-Gale_Murray                                                     None
# PM-MAR-C-Arsinoes                                                        None
# PM-MAR-D-Jezero                                                          None
# PM-MAR-D-Gale_Kimberley                                                  None
# PM-MER-C-H05_SU                                                          None
# PM-MER-GS-Rachmaninoff_5cc  <ul>Smooth Plains<ul> <li>sp<sup>6</sup>, 255-...
# PM-MER-MS-Beethoven                                                      None
# PM-MER-MS-H14_5cc           <ul>Smooth Plains<ul><li>sp, 255-190-190</li><...
# PM-MER-MS-H10_5cc           <ul>Smooth Plains<ul><li>sp, 255-190-190</li><...
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc           Smooth Plains, sp, 255-190-190Intermediate Pla...
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        TBD
# PM-MER-MS-Lermontov                                                      None
# PM-MER-MS-H14_3cc           <ul>Smooth Plains<ul><li>sp, 255-190-190</li><...
# PM-MER-C-H05                                                             None
# PM-MER-MS-H02_3cc           Smooth Plains, sp, 255-190-190Northern Smooth ...
# PM-MER-MS-H10_3cc           <ul>Smooth Plains<ul><li>sp, 255-190-190</li><...
# PM-MER-MS-Rembrandt         Proximal ejecta, PE, 76-230-0Hummocky material...
# PM-MER-MS-H05_3cc           Smooth Plains, sp, 255-190-190Intermediate Pla...
# PM-MER-C-Beethoven                                                        TBD
# PM-MOO-MS-Apollo11                                                       None
# PM-MOO-C-SPAA1_SU                                                        None
# PM-MOO-GS-SPAApollo_Detail  <ul>Copernican Crater<ul><li>Cc_SU2</li><li>Cc...
# PM-MOO-C-SPAApollo                                                       None
# PM-MOO-C-SPAApollo_SU                                                    None
# PM-MOO-MS-Apollo12                                                       None
# PM-MOO-MS-SPAApollo         Apl_craters_50kmApl_graben, 1 px line, (0, 0, ...
# PM-MOO-D-YutuGPR                                                         None
# PM-MOO-MS-Copernicus        SURROUNDING TERRAINS, Tt, 255-235-175VOLCANIC ...
#
#                                                            Stratigraphic info  \
# PM-MAR-MS-Crommelin                                                      None
# PM-MAR-C-Crommelin                                                       None
# PM-MAR-D-Oxia_Planum                                                     None
# PM-MAR-D-Crommelin                                                       None
# PM-MAR-MS-Arsinoes                                                       None
# PM-MAR-SI-Crommelin                                                      None
# PM-MAR-D-Gale_Murray                                                     None
# PM-MAR-C-Arsinoes                                                        None
# PM-MAR-D-Jezero                                                          None
# PM-MAR-D-Gale_Kimberley                                                  None
# PM-MER-C-H05_SU                                                          None
# PM-MER-GS-Rachmaninoff_5cc                                               None
# PM-MER-MS-Beethoven                                                      None
# PM-MER-MS-H14_5cc                                                        None
# PM-MER-MS-H10_5cc                                                        None
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc                                                        None
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                       None
# PM-MER-MS-Lermontov                                                      None
# PM-MER-MS-H14_3cc                                                        None
# PM-MER-C-H05                                                             None
# PM-MER-MS-H02_3cc           This map has an associated database of craters...
# PM-MER-MS-H10_3cc                                                        None
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc                                                        None
# PM-MER-C-Beethoven                                                       None
# PM-MOO-MS-Apollo11                                                       None
# PM-MOO-C-SPAA1_SU                                                        None
# PM-MOO-GS-SPAApollo_Detail                                               None
# PM-MOO-C-SPAApollo                                                       None
# PM-MOO-C-SPAApollo_SU                                                    None
# PM-MOO-MS-Apollo12                                                       None
# PM-MOO-MS-SPAApollo                                      Neukum et al. (2001)
# PM-MOO-D-YutuGPR                                                         None
# PM-MOO-MS-Copernicus                                                     None
#
#                                                                Other comments  \
# PM-MAR-MS-Crommelin                                                      None
# PM-MAR-C-Crommelin          Upper Left  (10008396.577,  369139.888) ( 11d ...
# PM-MAR-D-Oxia_Planum                                                     None
# PM-MAR-D-Crommelin                                                       None
# PM-MAR-MS-Arsinoes                                                       None
# PM-MAR-SI-Crommelin                                                      None
# PM-MAR-D-Gale_Murray                                                     None
# PM-MAR-C-Arsinoes                                                        None
# PM-MAR-D-Jezero                                                          None
# PM-MAR-D-Gale_Kimberley                                                  None
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc                                                         NaN
# PM-MER-MS-H10_5cc                                                         NaN
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc                          <Links to J. Maps review comments>
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc                                                         NaN
# PM-MER-C-H05                                                              NaN
# PM-MER-MS-H02_3cc           Since the mapping scale (~1:400k) was much hig...
# PM-MER-MS-H10_3cc                                                         NaN
# PM-MER-MS-Rembrandt                                                       NaN
# ...
# PM-MER-MS-H10_3cc           This research was initially funded by the UKRI...
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc           This research was initially funded by the UK S...
# PM-MER-C-Beethoven          SIMBIO-SYS/BepiColombo project (ASI-INAF agree...
# PM-MOO-MS-Apollo11                                                       None
# PM-MOO-C-SPAA1_SU                                                        None
# PM-MOO-GS-SPAApollo_Detail                                               None
# PM-MOO-C-SPAApollo                                                       None
# PM-MOO-C-SPAApollo_SU                                                    None
# PM-MOO-MS-Apollo12                                                       None
# PM-MOO-MS-SPAApollo         M. A. I. was supported by the German Science F...
# PM-MOO-D-YutuGPR                                                         None
# PM-MOO-MS-Copernicus                                                     None
#
#                             Map version  \
# PM-MAR-MS-Crommelin                 NaN
# PM-MAR-C-Crommelin                  NaN
# PM-MAR-D-Oxia_Planum                1.0
# PM-MAR-D-Crommelin                  1.0
# PM-MAR-MS-Arsinoes                  3.0
# PM-MAR-SI-Crommelin                 1.0
# PM-MAR-D-Gale_Murray                1.0
# PM-MAR-C-Arsinoes                   2.0
# PM-MAR-D-Jezero                     1.0
# PM-MAR-D-Gale_Kimberley             1.0
# PM-MER-C-H05_SU                     1.0
# PM-MER-GS-Rachmaninoff_5cc          1.0
# PM-MER-MS-Beethoven                 1.0
# PM-MER-MS-H14_5cc                   1.0
# PM-MER-MS-H10_5cc                   1.0
# PM-MER-SI-Rembrandt                 1.0
# PM-MER-MS-H05_5cc                   2.0
# PM-MER-D-Rembrandt                  1.0
# PM-MER-C-Rembrandt                  1.0
# PM-MER-MS-Lermontov                 1.0
# PM-MER-MS-H14_3cc                   1.0
# PM-MER-C-H05                        1.0
# PM-MER-MS-H02_3cc                   2.0
# PM-MER-MS-H10_3cc                   1.0
# PM-MER-MS-Rembrandt                 2.0
# PM-MER-MS-H05_3cc                   2.0
# PM-MER-C-Beethoven                  1.0
# PM-MOO-MS-Apollo11                  1.0
# PM-MOO-C-SPAA1_SU                   1.0
# PM-MOO-GS-SPAApollo_Detail          1.0
# PM-MOO-C-SPAApollo                  2.0
# PM-MOO-C-SPAApollo_SU               1.0
# PM-MOO-MS-Apollo12                  1.0
# PM-MOO-MS-SPAApollo                 NaN
# PM-MOO-D-YutuGPR                    1.0
# PM-MOO-MS-Copernicus                2.0
#
#                            Standards adhered to open formats for 3D mesh, materials and textures (obj, .mtl, .png)  \
# PM-MAR-MS-Crommelin                                                       NaN
# PM-MAR-C-Crommelin                                                        NaN
# PM-MAR-D-Oxia_Planum                                                     None
# PM-MAR-D-Crommelin                                                       None
# PM-MAR-MS-Arsinoes                                                        NaN
# PM-MAR-SI-Crommelin                                                       NaN
# PM-MAR-D-Gale_Murray                                                     None
# PM-MAR-C-Arsinoes                                                         NaN
# PM-MAR-D-Jezero                                                          None
# PM-MAR-D-Gale_Kimberley     3D meshes as Wavefront OBJ format (.obj mesh, ...
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc                                                         NaN
# PM-MER-MS-H10_5cc                                                         NaN
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc                                                         NaN
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc                                                         NaN
# PM-MER-C-H05                                                              NaN
# PM-MER-MS-H02_3cc                                                         NaN
# PM-MER-MS-H10_3cc                                                         NaN
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc                                                         NaN
# PM-MER-C-Beethoven                                                        NaN
# PM-MOO-MS-Apollo11                                                        NaN
# PM-MOO-C-SPAA1_SU                                                         NaN
# PM-MOO-GS-SPAApollo_Detail                                                NaN
# PM-MOO-C-SPAApollo                                                        NaN
# PM-MOO-C-SPAApollo_SU                                                     NaN
# PM-MOO-MS-Apollo12                                                        NaN
# PM-MOO-MS-SPAApollo                                                       NaN
# PM-MOO-D-YutuGPR                                                          NaN
# PM-MOO-MS-Copernicus                                                      NaN
#
#                                                                Polygon number  \
# PM-MAR-MS-Crommelin                                                       NaN
# PM-MAR-C-Crommelin                                                        NaN
# PM-MAR-D-Oxia_Planum                    N/A (generated by application engine)
# PM-MAR-D-Crommelin          Mesh in data repository (topography+geomodel):...
# PM-MAR-MS-Arsinoes                                                        NaN
# PM-MAR-SI-Crommelin                                                       NaN
# PM-MAR-D-Gale_Murray                                                     None
# PM-MAR-C-Arsinoes                                                         NaN
# PM-MAR-D-Jezero                         N/A (generated by application engine)
# PM-MAR-D-Gale_Kimberley     Orbital model: HiRISE DEM: 2.000.000\tGround-b...
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc                                                         NaN
# PM-MER-MS-H10_5cc                                                         NaN
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc                                                         NaN
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc                                                         NaN
# PM-MER-C-H05                                                              NaN
# PM-MER-MS-H02_3cc                                                         NaN
# PM-MER-MS-H10_3cc                                                         NaN
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc                                                         NaN
# PM-MER-C-Beethoven                                                        NaN
# PM-MOO-MS-Apollo11                                                        NaN
# PM-MOO-C-SPAA1_SU                                                        None
# PM-MOO-GS-SPAApollo_Detail                                               None
# PM-MOO-C-SPAApollo                                                        NaN
# PM-MOO-C-SPAApollo_SU                                                    None
# PM-MOO-MS-Apollo12                                                        NaN
# PM-MOO-MS-SPAApollo                                                       NaN
# PM-MOO-D-YutuGPR                                              < 30k triangles
# PM-MOO-MS-Copernicus                                                      NaN
#
#                                                   Number of attached textures  \
# PM-MAR-MS-Crommelin                                                       NaN
# PM-MAR-C-Crommelin                                                        NaN
# PM-MAR-D-Oxia_Planum                    N/A (generated by application engine)
# PM-MAR-D-Crommelin                       2 textures (MS map and image mosaic)
# PM-MAR-MS-Arsinoes                                                        NaN
# PM-MAR-SI-Crommelin                                                       NaN
# PM-MAR-D-Gale_Murray                     3 textures (MS map and image mosaic)
# PM-MAR-C-Arsinoes                                                         NaN
# PM-MAR-D-Jezero                         N/A (generated by application engine)
# PM-MAR-D-Gale_Kimberley     Orbital model: HiRISE DEM: 3 (1 per folder)\tG...
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc                                                         NaN
# PM-MER-MS-H10_5cc                                                         NaN
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc                                                         NaN
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc                                                         NaN
# PM-MER-C-H05                                                              NaN
# PM-MER-MS-H02_3cc                                                         NaN
# PM-MER-MS-H10_3cc                                                         NaN
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc                                                         NaN
# PM-MER-C-Beethoven                                                        NaN
# PM-MOO-MS-Apollo11                                                        NaN
# PM-MOO-C-SPAA1_SU                                                        None
# PM-MOO-GS-SPAApollo_Detail                                               None
# PM-MOO-C-SPAApollo                                                        NaN
# PM-MOO-C-SPAApollo_SU                                                    None
# PM-MOO-MS-Apollo12                                                        NaN
# PM-MOO-MS-SPAApollo                                                       NaN
# PM-MOO-D-YutuGPR                               2 textures (DEM and radargram)
# PM-MOO-MS-Copernicus                                                      NaN
#
#                                                              Modelling method
# PM-MAR-MS-Crommelin                                                       NaN
# PM-MAR-C-Crommelin                                                        NaN
# PM-MAR-D-Oxia_Planum        Orbital model: DEM Extrusion using application...
# PM-MAR-D-Crommelin          Topography: Stereo DEM extrusion; Geomodel: ex...
# PM-MAR-MS-Arsinoes                                                        NaN
# PM-MAR-SI-Crommelin                                                       NaN
# PM-MAR-D-Gale_Murray                                                     None
# PM-MAR-C-Arsinoes                                                         NaN
# PM-MAR-D-Jezero             Orbital model: DEM Extrusion using application...
# PM-MAR-D-Gale_Kimberley     Orbital model: DEM Extrusion\tGround-based mod...
# PM-MER-C-H05_SU                                                           NaN
# PM-MER-GS-Rachmaninoff_5cc                                                NaN
# PM-MER-MS-Beethoven                                                       NaN
# PM-MER-MS-H14_5cc                                                         NaN
# PM-MER-MS-H10_5cc                                                         NaN
# PM-MER-SI-Rembrandt                                                       NaN
# PM-MER-MS-H05_5cc                                                         NaN
# PM-MER-D-Rembrandt                                                        NaN
# PM-MER-C-Rembrandt                                                        NaN
# PM-MER-MS-Lermontov                                                       NaN
# PM-MER-MS-H14_3cc                                                         NaN
# PM-MER-C-H05                                                              NaN
# PM-MER-MS-H02_3cc                                                         NaN
# PM-MER-MS-H10_3cc                                                         NaN
# PM-MER-MS-Rembrandt                                                       NaN
# PM-MER-MS-H05_3cc                                                         NaN
# PM-MER-C-Beethoven                                                        NaN
# PM-MOO-MS-Apollo11                                                        NaN
# PM-MOO-C-SPAA1_SU                                                        None
# PM-MOO-GS-SPAApollo_Detail                                               None
# PM-MOO-C-SPAApollo                                                        NaN
# PM-MOO-C-SPAApollo_SU                                                    None
# PM-MOO-MS-Apollo12                                                        NaN
# PM-MOO-MS-SPAApollo                                                       NaN
# PM-MOO-D-YutuGPR                                Analytical explicit modelling
# PM-MOO-MS-Copernicus                                                      NaN

# %%
import json

table_tmp = json.loads(df_tmp.to_json(orient='records'))

# %%
table_tmp = { obj[pmid_column]:obj for obj in table_tmp }

# %%
table_clean = table_tmp
del table_tmp

# %% [markdown]
# ## Save JSON files in their respective packages
#
# Now we go back to where we began -- walking through the packages -- to write the resultant json tables.
# We will call them `meta.json`.

# %%
import json
from pathlib import Path

metafile = 'meta.json'

for pkg_dir in pkg_dirs:
    pkg_name = os.path.basename(pkg_dir)
    assert pkg_name in table_clean, f"{list(table_clean.keys())}"

    filepath = Path(pkg_dir) / metafile
    # if filepath.exists():
    #     print(f"Overwritting {filepath} ..")
    
    with open(filepath, 'w') as fp:
        _tab = table_clean[pkg_name]
        json.dump(_tab, fp)
        print(f"Package '{pkg_name}' metadata (README.md) written to '{filepath}'")
        
    # for filepath in glob(f"{pkg_dir}/*"):
    #     if os.path.basename(filepath).lower() == 'readme.md':
    #         print('--', filepath)
    #         table = validate_readme(filepath)
    #         assert pkg_name not in table_all
    #         table_all.update({ pkg_name: table })
# Out:
# Package 'PM-MAR-MS-Crommelin' metadata (README.md) written to 'data/publish_data/archive/mars/PM-MAR-MS-Crommelin/meta.json'
# Package 'PM-MAR-C-Crommelin' metadata (README.md) written to 'data/publish_data/archive/mars/PM-MAR-C-Crommelin/meta.json'
# Package 'PM-MAR-D-Oxia_Planum' metadata (README.md) written to 'data/publish_data/archive/mars/PM-MAR-D-Oxia_Planum/meta.json'
# Package 'PM-MAR-D-Crommelin' metadata (README.md) written to 'data/publish_data/archive/mars/PM-MAR-D-Crommelin/meta.json'
# Package 'PM-MAR-MS-Arsinoes' metadata (README.md) written to 'data/publish_data/archive/mars/PM-MAR-MS-Arsinoes/meta.json'
# Package 'PM-MAR-SI-Crommelin' metadata (README.md) written to 'data/publish_data/archive/mars/PM-MAR-SI-Crommelin/meta.json'
# Package 'PM-MAR-D-Gale_Murray' metadata (README.md) written to 'data/publish_data/archive/mars/PM-MAR-D-Gale_Murray/meta.json'
# Package 'PM-MAR-C-Arsinoes' metadata (README.md) written to 'data/publish_data/archive/mars/PM-MAR-C-Arsinoes/meta.json'
# Package 'PM-MAR-D-Jezero' metadata (README.md) written to 'data/publish_data/archive/mars/PM-MAR-D-Jezero/meta.json'
# Package 'PM-MAR-D-Gale_Kimberley' metadata (README.md) written to 'data/publish_data/archive/mars/PM-MAR-D-Gale_Kimberley/meta.json'
# Package 'PM-MER-C-H05_SU' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-C-H05_SU/meta.json'
# Package 'PM-MER-GS-Rachmaninoff_5cc' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-GS-Rachmaninoff_5cc/meta.json'
# Package 'PM-MER-MS-Beethoven' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-MS-Beethoven/meta.json'
# Package 'PM-MER-MS-H14_5cc' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-MS-H14_5cc/meta.json'
# Package 'PM-MER-MS-H10_5cc' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-MS-H10_5cc/meta.json'
# Package 'PM-MER-SI-Rembrandt' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-SI-Rembrandt/meta.json'
# Package 'PM-MER-MS-H05_5cc' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-MS-H05_5cc/meta.json'
# Package 'PM-MER-D-Rembrandt' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-D-Rembrandt/meta.json'
# Package 'PM-MER-C-Rembrandt' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-C-Rembrandt/meta.json'
# Package 'PM-MER-MS-Lermontov' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-MS-Lermontov/meta.json'
# Package 'PM-MER-MS-H14_3cc' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-MS-H14_3cc/meta.json'
# Package 'PM-MER-C-H05' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-C-H05/meta.json'
# Package 'PM-MER-MS-H02_3cc' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-MS-H02_3cc/meta.json'
# Package 'PM-MER-MS-H10_3cc' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-MS-H10_3cc/meta.json'
# Package 'PM-MER-MS-Rembrandt' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-MS-Rembrandt/meta.json'
# Package 'PM-MER-MS-H05_3cc' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-MS-H05_3cc/meta.json'
# Package 'PM-MER-C-Beethoven' metadata (README.md) written to 'data/publish_data/archive/mercury/PM-MER-C-Beethoven/meta.json'
# Package 'PM-MOO-MS-Apollo11' metadata (README.md) written to 'data/publish_data/archive/moon/PM-MOO-MS-Apollo11/meta.json'
# Package 'PM-MOO-C-SPAA1_SU' metadata (README.md) written to 'data/publish_data/archive/moon/PM-MOO-C-SPAA1_SU/meta.json'
# Package 'PM-MOO-GS-SPAApollo_Detail' metadata (README.md) written to 'data/publish_data/archive/moon/PM-MOO-GS-SPAApollo_Detail/meta.json'
# Package 'PM-MOO-C-SPAApollo' metadata (README.md) written to 'data/publish_data/archive/moon/PM-MOO-C-SPAApollo/meta.json'
# Package 'PM-MOO-C-SPAApollo_SU' metadata (README.md) written to 'data/publish_data/archive/moon/PM-MOO-C-SPAApollo_SU/meta.json'
# Package 'PM-MOO-MS-Apollo12' metadata (README.md) written to 'data/publish_data/archive/moon/PM-MOO-MS-Apollo12/meta.json'
# Package 'PM-MOO-MS-SPAApollo' metadata (README.md) written to 'data/publish_data/archive/moon/PM-MOO-MS-SPAApollo/meta.json'
# Package 'PM-MOO-D-YutuGPR' metadata (README.md) written to 'data/publish_data/archive/moon/PM-MOO-D-YutuGPR/meta.json'
# Package 'PM-MOO-MS-Copernicus' metadata (README.md) written to 'data/publish_data/archive/moon/PM-MOO-MS-Copernicus/meta.json'

# %%
# from importlib import reload
# reload(api.planmap)

# # payload = api.planmap.parse_readme_url('https://data.planmap.eu/pub/mars/PM-MAR-MS-Arsinoes/README.md')
# payload = api.planmap.parse_package(f'{PUB_DIR}/mars/PM-MAR-MS-Arsinoes')

# payload.add_files(f"{ZIP_DIR}/mars/PM-MAR-MS-Arsinoes.zip")

# payload.asdict()

# payload.create_files_payload()

# import api.invenio

# reload(api.invenio)

# # Invenio server
# #
# hostname = '10.72.2.28:5000'
# token = 'MJg5k2AYs5hr1YSXVKH4IifydN70WjUwcjbgxiKlxUaX2ETgB0nma4FiKZfx'

# client = api.invenio.InvenioClient(hostname, token)

# # Create a draft
# #
# resp = client.create_draft(payload)

# # print(resp)

# print(resp['id'])

# # Open record's page
# #
# import webbrowser

# webbrowser.open(resp['links']['self_html'])

# resp

# client.publish_draft(resp['id'])
